# %% [markdown]
# # Instagram Tracking Service Demo
#
# This notebook demonstrates how to use the Instagram tracking service to:
# - Create tracking tasks for Instagram profiles
# - Monitor both your own profiles and competitors
# - Analyze sentiment from comments
# - View tracking results and statistics
#
# ## Prerequisites
# - Valid user account (signup/login)
# - Instagram usernames to track
# - Server running with Instagram tracking service enabled

# %% [markdown]
# ## ◈ Initialization and Login

# %%
# set account
email = "watermelon@g.com"
password = "watermelon12345"





### Import required modules
from demo_modules import client, network
import json
from IPython.display import display, HTML, clear_output
import pandas as pd


client.init(
    "development"
)  # Change to "production" or "local" as needed for different base urls
print("✓ Client initialized successfully")


### Login (or signup if you don't have an account)
client.signup(email, password)  # will affect nothing if exist
success = client.login(email, password)

if success:
    print("✓ Login successful!")
else:
    print("❌ Login failed. Trying to signup...")
    # If login fails, try to signup
    success = client.signup(email, password)
    if success:
        print("✓ Signup successful! You are now logged in.")
    else:
        print("❌ Signup failed. Please check your credentials.")

print(f"Session token: {'✓ Available' if client.session_token else '❌ Not available'}")

# %% [markdown]
# ## ◈ Instagram Tracking Functions Declaration
#
# Let's create helper functions to interact with the Instagram tracking API.

# %%
from demo_modules.ig_tracking_functions import *

# %%
# new functions

def update_scrape_interval_task(task_id: str, new_interval_days: float):
    """Update the scrape interval for an existing tracking task"""
    print(f"🔄 Updating scrape interval for task {task_id} to {new_interval_days} days...")
    response = network.send(
        f"/codvid-ai/ig-tracking/update_scrape_interval/{task_id}",
        content={
            "scrape_interval_days": new_interval_days
        },
        session_token=client.session_token,
        method="PUT"
    )
    
    result = response.get_dict()
    if result and result.get("result"):
        print("✓ Scrape interval updated successfully!")
        return True
    else:
        print(f"❌ Failed to update scrape interval: {result.get('message', 'Unknown error') if result else 'No response'}")
        return False

# %% [markdown]
# ## 👀 View Tracking Tasks
#
# Let's see all the tracking tasks you have created.

# %%
# Get all tracking tasks
tasks = get_tracking_tasks()

def select_task_from_server():
    """Interactive function to select a task from server"""
    server_tasks = get_tracking_tasks()
    if not server_tasks or len(server_tasks) == 0:
        print("❌ No tasks found on server.")
        return None
    
    print("Available Instagram Tracking Tasks:")
    for idx, task in enumerate(server_tasks):
        profile = task.get('target_profile', 'unknown')
        ttype = 'Competitor' if task.get('is_competitor') else 'Own Profile'
        status = task.get('status', 'unknown')
        last_scraped = task.get('last_scraped', 'Never')
        print(f"  {idx+1}. @{profile} ({ttype}, status: {status})")
        print(f"      Last scraped: {last_scraped}")
        print(f"      Task ID: {task.get('_id', 'N/A')}")
        print()
    
    try:
        selection = int(input(f"Select a task by number (1-{len(server_tasks)}): "))
        if 1 <= selection <= len(server_tasks):
            selected_task = server_tasks[selection-1]
            selected_task_id = selected_task.get('_id')
            print(f"✅ Selected: @{selected_task.get('target_profile')} (Task ID: {selected_task_id})")
            return selected_task_id
        else:
            print("❌ Invalid selection.")
            return None
    except (ValueError, KeyboardInterrupt):
        print("❌ Invalid input or cancelled.")
        return None

if tasks:
    # Display tasks in a nice table format
    df = pd.DataFrame(tasks)
    df['type'] = df['is_competitor'].apply(lambda x: 'Competitor' if x else 'Own Profile')
    df['last_scraped'] = df['last_scraped'].fillna('Never')

    # Select columns to display
    display_df = df[['target_profile', 'type', 'status', 'last_scraped', 'next_scrape_due']].copy()
    display_df.columns = ['Instagram Profile', 'Type', 'Status', 'Last Scraped', 'Next Scrape Due']

    print("📊 Your Instagram Tracking Tasks:")
    display(display_df)

    # Store task IDs for later use
    all_task_ids = df['_id'].tolist()
    print(f"\n📋 Total tasks: {len(all_task_ids)}")

# %% [markdown]
# ## ➕ Create Tracking Tasks
#
# Let's create some tracking tasks for Instagram profiles. You can track both your own profiles and competitors.

# %%
# Create a tracking task for your own profile
if input("Enter [y] to confirm create:") == "y":
    profile = "pomatohk"  # Replace with your actual username
    task_id_own = create_tracking_task(profile, is_competitor=False)
    
    profile = "trialanderror924"  # Replace with your actual username
    task_id_own = create_tracking_task(profile, is_competitor=True)
else:
    print("cancelled")
    
# own_profile = "foodxtaste"  # Replace with your actual username
# task_id_own = create_tracking_task(own_profile, is_competitor=False)

# # Track a competitor
# competitor_profile = "joeie_foodie"  # Replace with competitor's username
# task_id_competitor = create_tracking_task(competitor_profile, is_competitor=True)

# %% [markdown]
# ## ⏰ Update Scrape Interval
#
# You can adjust the scraping frequency for an existing tracking task.

# %%
# Select a task to update its scrape interval
selected_task_id_for_update = smart_task_selector()

if selected_task_id_for_update:
    try:
        new_interval = float(input("Enter new scrape interval in days (float): "))
        print(new_interval, new_interval>0)
        if new_interval > 0:
            update_scrape_interval_task(selected_task_id_for_update, new_interval)
            print("💡 After updating, you can view tasks again to see the new 'Next Scrape Due' date.")
        else:
            print("❌ Invalid interval. Please enter a positive integer.")
    except ValueError:
        print("❌ Invalid input. Please enter a number.")
else:
    print("❌ No task selected for update.")

# %% [markdown]
# ## 🐎 Force Scrape a Task
#
# You can manually trigger scraping for any task. This will fetch the latest posts and analyze comments.

# %%
# Fetch latest tasks from server and let user select one
selected_task_id = smart_task_selector()

print(f"🎯 Selected task: {selected_task_id}")

# Get task details before scraping
task_details = get_task_details(selected_task_id)
if task_details:
    print(f"📱 Profile: @{task_details['target_profile']}")
    print(f"📊 Type: {'Competitor' if task_details['is_competitor'] else 'Own Profile'}")
    print(f"📅 Last scraped: {task_details.get('last_scraped', 'Never')}")
    
    # Force scrape
    success = force_scrape_task(selected_task_id)
    
    if success:
        print("💡 Done! Run the next cell to view the results after scraping completes.")
    else:
        print("❌ Scraping failed to initiate.")
else:
    print("❌ Could not get task details.")

# %% [markdown]
# ## 📖 View Task Details
#
# Let's examine the detailed results from a scraped task, including posts and comments.

# %%
# Select Task
all_tasks = get_tracking_tasks()
if all_tasks and isinstance(all_tasks, list) and len(all_tasks) > 0:
    print("Available Instagram Tracking Tasks:")
    for idx, task in enumerate(all_tasks):
        profile = task.get('target_profile', 'unknown')
        ttype = 'Competitor' if task.get('is_competitor') else 'Own Profile'
        status = task.get('status', 'unknown')
        print(f"  {idx+1}. @{profile} ({ttype}, status: {status}) [Task ID: {task.get('_id', 'N/A')}]")
    try:
        selection = int(input(f"\nSelect a task by number (1-{len(all_tasks)}): "))
        if 1 <= selection <= len(all_tasks):
            selected_task_id = all_tasks[selection-1]['_id']
        else:
            print("❌ Invalid selection.")
            selected_task_id = None
    except Exception as e:
        print("❌ Invalid input:", e)
        selected_task_id = None
else:
    print("❌ No tasks available on server. Create some tasks first!")
    selected_task_id = None

# Get detailed results for the selected task
if selected_task_id:
    task_details = get_task_details(selected_task_id)
    
    if task_details:
        print(json.dumps(task_details, indent=4, ensure_ascii=False))
    else:
        print("❌ No scraped data available. Try running the force scrape cell first and wait for completion.")
else:
    print("❌ No task selected.")
# Out:
# ✓ Found 1 tracking tasks
# Available Instagram Tracking Tasks:
#   1. @foodxtaste (Competitor, status: active) [Task ID: 62cbce9f-5886-48a8-9559-fa31867dcf80]
# {
#     "_id": "62cbce9f-5886-48a8-9559-fa31867dcf80",
#     "created_at": 1754725200,
#     "is_competitor": true,
#     "last_scraped": 1754726504,
#     "next_scrape_due": 1754899304,
#     "schema_version": "1.3",
#     "scrape_interval_days": 2.0,
#     "status": "active",
#     "target_profile": "foodxtaste",
#     "target_profile_data": {
#         "biography": "食盡港九新界✍️美食日記  ୧(๑•̀ᴗ•́๑)୨\n🍔地區搵食 e.g #foodxtaste旺角\n🍺一起「吃 喝 玩 樂」👅\n🥑Reels努力製作中 🎞️",
#         "followers": 367370,
#         "following": 476,
#         "full_name": "平民吃貨😋香港美食🤍𝓢𝓲𝓷𝓬𝓮 ²⁰¹⁵",
#         "icon_pic_url": "https://scontent-nrt1-1.cdninstagram.com/v/t51.2885-19/465596149_825645562840760_2763048262223810864_n.jpg?stp=dst-jpg_s320x320_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6InByb2ZpbGVfcGljLmRqYW5nby4xMDgwLmMyIn0&_nc_ht=scontent-nrt1-1.cdninstagram.com&_nc_cat=108&_nc_oc=Q6cZ2QGoft5c6UKw8Du59Dwl74pwnYuDiM3rYFeJQPW_Y8ucRKxJbX_qXGpjjnE1fSh7Zhs&_nc_ohc=SJB28J1vmFAQ7kNvwGSDHR1&_nc_gid=upfnFBbHLmWXri91He1ivw&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfWTi2yHO-8I4pjiR4rV9Ffs7Y14IwobPGVr53hD7cNUYw&oe=689CC8C0&_nc_sid=8b3546",
#         "ig_tv_video_count": 0,
#         "posts_count": 1414,
#         "scraped_posts": [
#             {
#                 "caption": "✨Omakase拖羅都有得任食😳✨\n\n邊個話食Omakase會唔夠飽😎\n套餐本身已經非常豐富 先有先付三品\n三文魚子豆腐、日本湯葉豆皮、螺\n再嚟係櫻花蝦茶碗蒸🥄\n日本生蠔都有三款不同品種 配搭不同食法🦪\n之後再食時令刺身🥢\n分別係魚子醬粟米蓉甘蝦、活赤貝醃製三文魚子秋葵\n煙燻鰹魚、日本海膽最中餅、間白魚卷 \n再有季節料理-慢煮鮑魚、北海道白粟米\n\n食到呢度已經飽咗差唔多一半🙂‍↕️\n戲肉手握壽司10貫🤩\n除咗海膽杯之外 其他壽司全部都可以無限追加\n大家一路食嘅時候 可以mark低自己鍾意嘅壽司\n師傅話最勁嘅客人食左接近50件😳大癲\n\n壽司中比較特別蜜柑鯛魚 喺飼料上加入咗蜜柑🍊\n所以食落會帶點柑橘香風味\n個人最喜歡新鮮銀鱈魚 無急凍過直送到港\n炙燒完超香 配埋白麵豉一齊食\n回本之選 拖羅壽司都有得任食 真大癲🥹\n生日可以免費upgrade甜品拼盤🎂\n仲會播住生日歌音樂盒 滿滿儀式感\n\n每位$1680（原價$1980）\n\n✨提前預訂✨\n二人同行 一人半價\n三人同行 第二第三位半價\n\n🖇️霜瀛 @shimoumi_sushi \n📍尖沙咀金馬倫道33號The Cameron 1樓102號舖\n☎️31888007\n\n#foodxtaste尖沙咀\n#尖沙咀美食 #omakase #任食 #拖羅 #生日飯",
#                 "comments_count": 23,
#                 "hashtags": [
#                     "foodxtaste尖沙咀",
#                     "尖沙咀美食",
#                     "omakase",
#                     "任食",
#                     "拖羅",
#                     "生日飯"
#                 ],
#                 "likes_count": 918,
#                 "mentions": [
#                     "shimoumi_sushi"
#                 ],
#                 "post_id": "3691654467025342629",
#                 "post_url": "https://www.instagram.com/p/DM7ZC20h5Cl/",
#                 "timestamp": 1754299500,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "eat__dessert",
#                         "sentiment": "positive",
#                         "text": "看起來超夢幻！",
#                         "timestamp": 1754306191
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkol_foodie",
#                         "sentiment": "positive",
#                         "text": "真係好吸引呀😍",
#                         "timestamp": 1754302604
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hok__kong",
#                         "sentiment": "positive",
#                         "text": "好高質👍",
#                         "timestamp": 1754307645
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkfoodie.foodislife",
#                         "sentiment": "positive",
#                         "text": "😍❤️",
#                         "timestamp": 1754325493
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "mizjoe1",
#                         "sentiment": "neutral",
#                         "text": "幾錢？",
#                         "timestamp": 1754301850
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "mimiballball",
#                         "sentiment": "neutral",
#                         "text": "@lmc098",
#                         "timestamp": 1754461684
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "fafawa",
#                         "sentiment": "neutral",
#                         "text": "1680喎",
#                         "timestamp": 1754621916
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "marcooo0612",
#                         "sentiment": "neutral",
#                         "text": "無限追加係個set包埋定逐件計錢先？\n講清楚好喎",
#                         "timestamp": 1754444920
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "chunkityuenhk",
#                         "sentiment": "neutral",
#                         "text": "$？",
#                         "timestamp": 1754386826
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🍣🍣",
#                         "timestamp": 1754299877
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "positive",
#                         "text": "提前預訂 二人同行 一人半價🤤",
#                         "timestamp": 1754300054
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winnielee979",
#                         "sentiment": "neutral",
#                         "text": "$ ?",
#                         "timestamp": 1754332673
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "toney98765",
#                         "sentiment": "positive",
#                         "text": "原來美食還能這樣精心設計，厲害👍",
#                         "timestamp": 1754622282
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "rubi.yu",
#                         "sentiment": "neutral",
#                         "text": "??",
#                         "timestamp": 1754321232
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hugohimhim",
#                         "sentiment": "neutral",
#                         "text": "邊度？",
#                         "timestamp": 1754487447
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "siuyanyan311",
#                         "sentiment": "neutral",
#                         "text": "每位1680係咪已經係二人同行，一人半價。優惠咗後每位嘅價錢？",
#                         "timestamp": 1754665742
#                     },
#                     {
#                         "likes_count": 4,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "positive",
#                         "text": "拖羅都有得任食?最勁客人仲食左接近50件🫨",
#                         "timestamp": 1754299868
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 33647
#             },
#             {
#                 "caption": "✨重溫回憶舊時光🥢✨\n\n平日都爆晒場嘅南山邨 鑊氣小炒🔥\n相信係唔少街坊/大學生回憶😗\n今次去重溫回憶舊時光🍂\n先嚟一人一杯凍朱古力🍫面頭有超邪惡忌廉😎\n仲有夏天飲啱晒嘅益力多沙冰❗️\n小炒必點招牌風沙雞 肉質嫩滑恰到好處😙\n火焰蜜椒牛柳粒 個火都燒得幾耐\n牛柳粒唔錯 口感軟腍醬汁濃厚\n送飯一流 仲有大大粒薯仔🤣\n另外南乳炸豬手係熱賣排行榜嘅No.1🥇\n豬手又淡淡南乳味 在另上一碟南乳醬\n個皮煙靭香脆 滿滿骨膠原☺️\n仲有啫啫通菜煲 現場即啫好香🤩\n叫多碟椒鹽鮮魷 整體食物種類真係超多選擇😳\n傳統 新式嘅小菜都有 食飽仲可以去打個卡📷\n\n南乳炸豬手$118\n風沙雞 半隻$168/一隻$288\n火焰蜜椒牛柳粒$128\n椒鹽鮮魷$128\n啫啫通菜煲$98\n\n🖇️品香樓中西風味餐廳\n📍石硤尾大坑東道111號南山邨南山商場平台204-205及210-213號舖\n☎️2778 8791\n\n#foodxtaste石硤尾\n#石硤尾美食 #南山邨 #小炒",
#                 "comments_count": 51,
#                 "hashtags": [
#                     "foodxtaste石硤尾",
#                     "石硤尾美食",
#                     "南山邨",
#                     "小炒"
#                 ],
#                 "likes_count": 3562,
#                 "mentions": [],
#                 "post_id": "3677221674383870687",
#                 "post_url": "https://www.instagram.com/p/DMIHaFOBIrf/",
#                 "timestamp": 1752579000,
#                 "top_comments": [
#                     {
#                         "likes_count": 4,
#                         "owner_username": "thomzonchan",
#                         "sentiment": "negative",
#                         "text": "隔離南豐餐廳好食好多👍🏽",
#                         "timestamp": 1752762170
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "tako124",
#                         "sentiment": "positive",
#                         "text": "😍朱古力好飲",
#                         "timestamp": 1752586734
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "pictures.of.the.world9",
#                         "sentiment": "positive",
#                         "text": "😍😍",
#                         "timestamp": 1752628165
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkol_foodie",
#                         "sentiment": "positive",
#                         "text": "風沙雞好香喎😍😍",
#                         "timestamp": 1752604310
#                     },
#                     {
#                         "likes_count": 4,
#                         "owner_username": "m_mei2_",
#                         "sentiment": "negative",
#                         "text": "隔咗成10年冇去過\n月頭去食間舖變得冷清清，同埋食物冇以前咁好食，飲品就保持水準，上菜速度好快，通菜煲同雞都ok ，反而豬手同椒鹽魷魚好淡味，火焰牛柳粒薯仔出色好多",
#                         "timestamp": 1752744485
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "p.yeung",
#                         "sentiment": "negative",
#                         "text": "無想像中好食，食既係回憶",
#                         "timestamp": 1752623039
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "r.ngngng.r",
#                         "sentiment": "negative",
#                         "text": "自從出咗名之後已經差咗好多，反而街市樓下新餐廳有驚喜，可以一試！",
#                         "timestamp": 1752641870
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "fai.fat",
#                         "sentiment": "negative",
#                         "text": "20年前，就真係好好食",
#                         "timestamp": 1753183809
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "trowa_kong",
#                         "sentiment": "negative",
#                         "text": "已經差咗好多🫠",
#                         "timestamp": 1752597940
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🥢🥢",
#                         "timestamp": 1752585064
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "mandy_wong_26",
#                         "sentiment": "negative",
#                         "text": "食咗廿多年但已經差咗好多！btw...來食，你要忍耐！",
#                         "timestamp": 1752656470
#                     },
#                     {
#                         "likes_count": 46,
#                         "owner_username": "channam",
#                         "sentiment": "negative",
#                         "text": "已經無以前咁好食，而且又貴又嘈，我明白佢個位係公屋單位改裝，但啲位唔好排到咁密，好困聲！食飯要全程大叫咁",
#                         "timestamp": 1752593843
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "roy.gorgor",
#                         "sentiment": "negative",
#                         "text": "中肯啲講句啊，而家真係貴得黎唔好食",
#                         "timestamp": 1752754466
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "bi_20232023",
#                         "sentiment": "negative",
#                         "text": "D食物份量一年比一年少.\n價錢就年年加",
#                         "timestamp": 1752656685
#                     },
#                     {
#                         "likes_count": 16,
#                         "owner_username": "moni502",
#                         "sentiment": "negative",
#                         "text": "貴左好多，啲位坐得好逼，無去好耐了",
#                         "timestamp": 1752602223
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "holandtom168",
#                         "sentiment": "positive",
#                         "text": "😍",
#                         "timestamp": 1754638921
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hdusjsnsksksi",
#                         "sentiment": "positive",
#                         "text": "味道肯定很棒吧",
#                         "timestamp": 1754637571
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "anna.261887",
#                         "sentiment": "positive",
#                         "text": "正😍😍",
#                         "timestamp": 1754129146
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "alisonlyman68818w",
#                         "sentiment": "positive",
#                         "text": "🔥🔥🔥",
#                         "timestamp": 1753966008
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cky_amos",
#                         "sentiment": "neutral",
#                         "text": "以前住深水埗 成日去食 後來搬左屋 就冇食過😢",
#                         "timestamp": 1753436272
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sharetravel2025",
#                         "sentiment": "positive",
#                         "text": "😍",
#                         "timestamp": 1753342601
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "duch0807",
#                         "sentiment": "positive",
#                         "text": "看样子不错呢👏",
#                         "timestamp": 1753334143
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sae_0877",
#                         "sentiment": "positive",
#                         "text": "料很多呀",
#                         "timestamp": 1753322297
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "so_nara1987",
#                         "sentiment": "neutral",
#                         "text": "證明多後生仔先有夜經濟",
#                         "timestamp": 1753291373
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "danielhung2008",
#                         "sentiment": "neutral",
#                         "text": "犀利，我記得 20 年前食，比較普通",
#                         "timestamp": 1753286927
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kevinchan6498",
#                         "sentiment": "neutral",
#                         "text": "究竟石硤尾定係南山邨？",
#                         "timestamp": 1753280204
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "jccs112",
#                         "sentiment": "negative",
#                         "text": "過往每週去一次  每次都有五六位 招呼差  以後都唔去 改去樓下餐廳",
#                         "timestamp": 1753277486
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "joeychoi329",
#                         "sentiment": "negative",
#                         "text": "生意好就唔使放上網啦！",
#                         "timestamp": 1753239476
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "steven_cheng_1027",
#                         "sentiment": "negative",
#                         "text": "不知所謂 ，哩間嘢伙記成日要俾人打果隻。",
#                         "timestamp": 1753236649
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "fmarcofan",
#                         "sentiment": "negative",
#                         "text": "垃圾級",
#                         "timestamp": 1753183215
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "abelyipyip",
#                         "sentiment": "positive",
#                         "text": "😍😍睇落就忍不住沖沖沖",
#                         "timestamp": 1753147960
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kristy.6210",
#                         "sentiment": "positive",
#                         "text": "😋😋😋",
#                         "timestamp": 1753095975
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ca_cayin",
#                         "sentiment": "neutral",
#                         "text": "@beatrix.to @tang.ky  我地去過尼間😂",
#                         "timestamp": 1752855702
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "l61802360",
#                         "sentiment": "negative",
#                         "text": "以前 D 侍應 同老闆 好惡",
#                         "timestamp": 1752840990
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "l61802360",
#                         "sentiment": "neutral",
#                         "text": "華，，，炸物",
#                         "timestamp": 1752840930
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winnie.leung3",
#                         "sentiment": "negative",
#                         "text": "完全不覺得好食，南豐或新金華都比佢好食",
#                         "timestamp": 1752835734
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hongkonger_in_nigeria",
#                         "sentiment": "negative",
#                         "text": "大半年前去過，所有招牌菜都唔掂，南乳豬手無咩味，風沙雞啲雞肉鞋烚烚，蠔餅炸到燶底，我媽對食無咩要求都話唔再去食",
#                         "timestamp": 1752830006
#                     },
#                     {
#                         "likes_count": 5,
#                         "owner_username": "siuboooooooo",
#                         "sentiment": "negative",
#                         "text": "廣告真差，啲配樂都係求其搵一首。。。",
#                         "timestamp": 1752778926
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "pastawild",
#                         "sentiment": "negative",
#                         "text": "根本就垃圾",
#                         "timestamp": 1752763343
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "anniedo.do",
#                         "sentiment": "negative",
#                         "text": "服務差，投訴完唔理你",
#                         "timestamp": 1752755295
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "chanroy823",
#                         "sentiment": "negative",
#                         "text": "以前好生意就吾憂做，所以服務非常差，而家静左又難食，仲邊有人去幫襯，我都起碼10年無比錢佢賺😂",
#                         "timestamp": 1752755158
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "ssandykwan",
#                         "sentiment": "negative",
#                         "text": "又嘈",
#                         "timestamp": 1752753715
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ssandykwan",
#                         "sentiment": "negative",
#                         "text": "難吃",
#                         "timestamp": 1752753700
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lukmansin",
#                         "sentiment": "negative",
#                         "text": "又係廣告🙂",
#                         "timestamp": 1752740757
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "maniwu_wu",
#                         "sentiment": "negative",
#                         "text": "又貴又差又難食😓沒下次",
#                         "timestamp": 1752691453
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "jeffkwokck",
#                         "sentiment": "negative",
#                         "text": "讀緊果時去食 食食下隔離圍台 成台彈起身尖叫衝出鋪 原來跌咗隻老鼠落嚟😂 個廚房佬淡淡定拎掃把出嚟 一嘢拍死掃走 倒落我隔離個垃圾桶到 即刻唔食 走 之後都冇食過😂",
#                         "timestamp": 1752652178
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "janlau819",
#                         "sentiment": "negative",
#                         "text": "又難食又貴",
#                         "timestamp": 1752650499
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hok__kong",
#                         "sentiment": "positive",
#                         "text": "正呀！👍",
#                         "timestamp": 1752635308
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "discount_code_nmr266",
#                         "sentiment": "positive",
#                         "text": "😍😍😍😍🔥",
#                         "timestamp": 1752619468
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 8771
#             },
#             {
#                 "caption": "✨屯門海邊走走🥢✨\n\n走入屯門慢活行一下 感覺幾舒服☺️\n食個蒜辣冷麵 $10/5包\n仲有$11/2球 大大球雪糕🍨\n$6蚊個營多撈麵 買兩個仲平啲$10/2個😳\n再去海邊走走 又一day😙\n\n📍冰山一國\n\n#foodxtaste屯門\n#屯門美食 #掃街 #小食 #雪糕 #冷麵 #撈麵",
#                 "comments_count": 144,
#                 "hashtags": [
#                     "foodxtaste屯門",
#                     "屯門美食",
#                     "掃街",
#                     "小食",
#                     "雪糕",
#                     "冷麵",
#                     "撈麵"
#                 ],
#                 "likes_count": 26907,
#                 "mentions": [],
#                 "post_id": "3654844195354831743",
#                 "post_url": "https://www.instagram.com/p/DK4nW51het_/",
#                 "timestamp": 1749911400,
#                 "top_comments": [
#                     {
#                         "likes_count": 5,
#                         "owner_username": "tsz_chan1096",
#                         "sentiment": "positive",
#                         "text": "啊、呢個近我屋企撘轉鐵就到😍😍😍、等好天氣就去食👏",
#                         "timestamp": 1749921484
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "lolohohololohoohholohlohohohll",
#                         "sentiment": "positive",
#                         "text": "呢間正 冷麵好味",
#                         "timestamp": 1749955902
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "thyyy331",
#                         "sentiment": "positive",
#                         "text": "😍😍好食 屋企人住呢邊 之前成日去",
#                         "timestamp": 1749916317
#                     },
#                     {
#                         "likes_count": 62,
#                         "owner_username": "connie90210",
#                         "sentiment": "positive",
#                         "text": "嗰個烘燶麵包好正喎",
#                         "timestamp": 1749916323
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "be_lf_or_",
#                         "sentiment": "neutral",
#                         "text": "系我樓下",
#                         "timestamp": 1749916695
#                     },
#                     {
#                         "likes_count": 70,
#                         "owner_username": "_lin.my",
#                         "sentiment": "positive",
#                         "text": "屯門牛 我驕傲",
#                         "timestamp": 1749951877
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "l0ve_mylife",
#                         "sentiment": "positive",
#                         "text": "$10/5包？ 10幾年前嘅價錢黎架喎",
#                         "timestamp": 1750508826
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "carson_0526",
#                         "sentiment": "neutral",
#                         "text": "求地址",
#                         "timestamp": 1750015424
#                     },
#                     {
#                         "likes_count": 5,
#                         "owner_username": "2c22benjamin",
#                         "sentiment": "neutral",
#                         "text": "條片應該好耐之前架wo，做咩而家先po🙃",
#                         "timestamp": 1749984168
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "stevenhin_",
#                         "sentiment": "positive",
#                         "text": "我小學食係5蚊兩球雪糕🙌",
#                         "timestamp": 1749952766
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "kanicee_lau_fans_club",
#                         "sentiment": "positive",
#                         "text": "呢間真係超好食同埋好抵",
#                         "timestamp": 1749956333
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "2c22benjamin",
#                         "sentiment": "neutral",
#                         "text": "其實之前隔離仲有個營多平少少，而家搬左去前面",
#                         "timestamp": 1749984020
#                     },
#                     {
#                         "likes_count": 325,
#                         "owner_username": "chung.on.estate.checkitout__hk",
#                         "sentiment": "negative",
#                         "text": "可惜喺屯門，好遠😢",
#                         "timestamp": 1749912272
#                     },
#                     {
#                         "likes_count": 7,
#                         "owner_username": "1ye3n._",
#                         "sentiment": "neutral",
#                         "text": "其實我住屯門都唔知有呢啲嘢😌",
#                         "timestamp": 1750004127
#                     },
#                     {
#                         "likes_count": 26,
#                         "owner_username": "lu.cas.05_17",
#                         "sentiment": "neutral",
#                         "text": "我屋企樓下🥸",
#                         "timestamp": 1749963183
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "anson_ptcg",
#                         "sentiment": "neutral",
#                         "text": "我通常食開新北江嗰邊嗰間",
#                         "timestamp": 1753807899
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "aimeechan620",
#                         "sentiment": "positive",
#                         "text": "啲回憶都湧晒上嚟🥲🥹♥︎",
#                         "timestamp": 1753617001
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "fontsky0013",
#                         "sentiment": "neutral",
#                         "text": "屯門嘅唔係都食心思思㗎咩",
#                         "timestamp": 1753464427
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sae_0877",
#                         "sentiment": "neutral",
#                         "text": "你要吃幾樣？",
#                         "timestamp": 1753322331
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "leungpakkinethan",
#                         "sentiment": "positive",
#                         "text": "童年回憶😢",
#                         "timestamp": 1753273691
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kiki._.8.1333",
#                         "sentiment": "neutral",
#                         "text": "天一都有",
#                         "timestamp": 1753272441
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "banana._.cclb",
#                         "sentiment": "neutral",
#                         "text": "大家我屋企樓下",
#                         "timestamp": 1753123283
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "moomilove20141025",
#                         "sentiment": "positive",
#                         "text": "大家都係住那邊喔，回憶呀",
#                         "timestamp": 1753109883
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kimberlychinwing",
#                         "sentiment": "neutral",
#                         "text": "天月有",
#                         "timestamp": 1752762968
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lovetwtwtw999",
#                         "sentiment": "neutral",
#                         "text": "命運的真相-改變命運的原理\n\n每個人的命運，簡單來說是根據前世今生所造的善與惡綜合計算而成。造的善很大，惡很少，命運就會非常好。造的惡很大，善很少，命運就會非常不幸。所以簡單來說，如果想要改變不幸的命運，或者想要好的命運繼續保持下去，就需要努力做善事，停止做惡事。其中，影響力很大的善事，例如：拯救人與動物的生命、救災賑災、拯救窮人......等等。影響力很大的惡事，例如：手淫、墮胎、婚外情、殺生食肉、詐騙搶劫......等等。",
#                         "timestamp": 1752761060
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "asakumi4114",
#                         "sentiment": "positive",
#                         "text": "Where is this I need to go there",
#                         "timestamp": 1752646172
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "anji.locking",
#                         "sentiment": "neutral",
#                         "text": "我屋企樓下嗰間😂",
#                         "timestamp": 1752641788
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "marcuscow1128",
#                         "sentiment": "neutral",
#                         "text": "地方和有吃",
#                         "timestamp": 1752596399
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "marcuscow1128",
#                         "sentiment": "neutral",
#                         "text": "那個",
#                         "timestamp": 1752596358
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "marcuscow1128",
#                         "sentiment": "neutral",
#                         "text": "我平時都有吃",
#                         "timestamp": 1752596327
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "michelle_lovr",
#                         "sentiment": "positive",
#                         "text": "that looks so good",
#                         "timestamp": 1752517190
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "disneyfied._.ashley",
#                         "sentiment": "neutral",
#                         "text": "心思思平啲",
#                         "timestamp": 1752504972
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "qwerhjb4444",
#                         "sentiment": "positive",
#                         "text": "端着一边走一边吃肯定不错",
#                         "timestamp": 1752481853
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "nidie0614",
#                         "sentiment": "neutral",
#                         "text": "屯門蝴蝶灣啟豐商場2樓",
#                         "timestamp": 1752405295
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kuossyuli885",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1752224909
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "haa_069",
#                         "sentiment": "neutral",
#                         "text": "看起來像炒泡麵！",
#                         "timestamp": 1752152516
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sky_chan13907",
#                         "sentiment": "neutral",
#                         "text": "聚興樓有六蚊撈麵",
#                         "timestamp": 1752039559
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "pictures.of.the.world9",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1752024095
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "che_arvin",
#                         "sentiment": "positive",
#                         "text": "让我想起了我的童年",
#                         "timestamp": 1751934935
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ycl910610",
#                         "sentiment": "neutral",
#                         "text": "單身喜歡悠閒的日子，想找一個和我匹配的人。❤️",
#                         "timestamp": 1751801316
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "saupei.hk",
#                         "sentiment": "negative",
#                         "text": "收皮啦",
#                         "timestamp": 1751723895
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "renleiren",
#                         "sentiment": "positive",
#                         "text": "😢😍😍😍",
#                         "timestamp": 1751718999
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "renleiren",
#                         "sentiment": "positive",
#                         "text": "好平",
#                         "timestamp": 1751718994
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kimberlyferguson760nkr",
#                         "sentiment": "positive",
#                         "text": "👏👏👏",
#                         "timestamp": 1751391433
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "f.on_ld",
#                         "sentiment": "neutral",
#                         "text": "我屋企樓下😮",
#                         "timestamp": 1751199273
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "marco__lau__4458",
#                         "sentiment": "neutral",
#                         "text": "@gabriel_lch  新北江果間？",
#                         "timestamp": 1751191292
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "tracykwok1",
#                         "sentiment": "neutral",
#                         "text": "吓，好內在蝴蝶邨，輕鐵總站。",
#                         "timestamp": 1751063401
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ed._losiu",
#                         "sentiment": "positive",
#                         "text": "以前十蚊十包",
#                         "timestamp": 1751022484
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "0704_jackie",
#                         "sentiment": "positive",
#                         "text": "👏👏👏",
#                         "timestamp": 1750992575
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "scott_pang1208",
#                         "sentiment": "neutral",
#                         "text": "我長大嘅地方🥹🥹",
#                         "timestamp": 1750942574
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ibeprofe_n",
#                         "sentiment": "positive",
#                         "text": "there was a store next to this one, had 5 dollar price tags on food.. the ramen was insanely good. i miss the ramen auntie. 😢, and yes the prices are okay in the store your showing, damn tasty alright",
#                         "timestamp": 1750938832
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "james2001321",
#                         "sentiment": "positive",
#                         "text": "我以前$4😂",
#                         "timestamp": 1750825965
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "c_syu510",
#                         "sentiment": "positive",
#                         "text": "中學回憶",
#                         "timestamp": 1750786271
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sink_macau",
#                         "sentiment": "neutral",
#                         "text": "屯門海戰（1521年）係香港土地歷史上早期抗侵略一幕。當年葡萄牙殖民者圖喺華南擴張，霸佔屯門，操控貿易。當地人喺明軍帶領下迎擊，成功趕走外敵。雖然明朝本身都係極權政權，但呢場仗反映咗香港一帶居民唔肯俾外來勢力胡亂侵佔土地、干預生活。今日我哋面對嘅強權唔再係西洋殖民者，而係一個打壓自由、文化同身份嘅政權。屯門之戰提醒我哋，守土有責，唔論外敵定內壓，香港人都有權捍衛自己嘅家園。",
#                         "timestamp": 1750627651
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "wolf25.fwgw25",
#                         "sentiment": "negative",
#                         "text": "我现在在那里  冰山一國好难吃  我建议你去心思思",
#                         "timestamp": 1750496338
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "g132_4hk",
#                         "sentiment": "negative",
#                         "text": "衞生？",
#                         "timestamp": 1750482383
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "the.realgoose69",
#                         "sentiment": "positive",
#                         "text": "shi tasted ahh",
#                         "timestamp": 1750471898
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "only.aiyno",
#                         "sentiment": "positive",
#                         "text": "我中學一星期食兩次嗰間😍",
#                         "timestamp": 1750402739
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "tttt0188aa",
#                         "sentiment": "neutral",
#                         "text": "所以地址？",
#                         "timestamp": 1750288186
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "love_lovely_teemo",
#                         "sentiment": "neutral",
#                         "text": "@jeremy93_pawfectto 係烘燶麵包呀😮",
#                         "timestamp": 1750250535
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "taobao._.alvin",
#                         "sentiment": "neutral",
#                         "text": "@w._l.smart",
#                         "timestamp": 1750245151
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hk_hin2025",
#                         "sentiment": "negative",
#                         "text": "成日計住要平，去啲印尼舖買袋營多自己煮啦",
#                         "timestamp": 1750232438
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lochnessa_330",
#                         "sentiment": "positive",
#                         "text": "冰山一角我摯愛😍😍超平",
#                         "timestamp": 1750222059
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "m4_chingka_2004",
#                         "sentiment": "negative",
#                         "text": "葵廣貴左。。。😢",
#                         "timestamp": 1750200718
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "collincollinmama",
#                         "sentiment": "neutral",
#                         "text": "同新北江差唔多",
#                         "timestamp": 1750176680
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "dgdjvdh",
#                         "sentiment": "positive",
#                         "text": "其實屯門真係好多好野食",
#                         "timestamp": 1750119548
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "chenjunxi29",
#                         "sentiment": "positive",
#                         "text": "食過 抵食",
#                         "timestamp": 1750086640
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hasto_3",
#                         "sentiment": "positive",
#                         "text": "呢啲小店係得返屯元天先有，冇人逼租，係市區啲鋪位三年換一間",
#                         "timestamp": 1750079069
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ttc.713",
#                         "sentiment": "neutral",
#                         "text": "直程喺屋企樓下🤯",
#                         "timestamp": 1750064333
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kovirla.0403",
#                         "sentiment": "positive",
#                         "text": "可以去埋蝴蝶灣，日落一流🤪",
#                         "timestamp": 1750063390
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "jc08119",
#                         "sentiment": "negative",
#                         "text": "瀉藥😂",
#                         "timestamp": 1750063345
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "purinmon17",
#                         "sentiment": "neutral",
#                         "text": "係悅湖山莊，輕鐵兆禧站行過去10分鐘，屯門碼頭行過去大約15分鐘",
#                         "timestamp": 1750060459
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "yaosheng945",
#                         "sentiment": "neutral",
#                         "text": "葵芳都有得食",
#                         "timestamp": 1750046434
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "__.11_07.__",
#                         "sentiment": "positive",
#                         "text": "中學回憶😭🥹有冇屯門友有共鳴",
#                         "timestamp": 1750041068
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "harry_1100.of",
#                         "sentiment": "positive",
#                         "text": "放學成日去😂😂",
#                         "timestamp": 1750033758
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "candywky621",
#                         "sentiment": "negative",
#                         "text": "味道👅不錯\n但一包eg:鵪鶉蛋一粒、龍門卷兩薄片⋯⋯\n比十年前份量少好多唔抵食\n反而想試吓撈麵，睇吓同自己煮有乜分別",
#                         "timestamp": 1750031039
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "shikaco01",
#                         "sentiment": "negative",
#                         "text": "專登入屯門買$6包既撈麵，不如我去買$10一紮嘅撈麵自己煮😂",
#                         "timestamp": 1750027034
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "funnyhkgse",
#                         "sentiment": "negative",
#                         "text": "😢😢😢屯門區同20年前相比都變咗好多",
#                         "timestamp": 1750026341
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "jansenaupaklok",
#                         "sentiment": "neutral",
#                         "text": "啟豐？",
#                         "timestamp": 1750026297
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lpy.luka0623",
#                         "sentiment": "neutral",
#                         "text": "旺角有10蚊2球雪糕",
#                         "timestamp": 1749999499
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "wh_old_six_",
#                         "sentiment": "neutral",
#                         "text": "5元",
#                         "timestamp": 1749991948
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "___la19m___",
#                         "sentiment": "positive",
#                         "text": "我童年😭😭😭",
#                         "timestamp": 1749991706
#                     },
#                     {
#                         "likes_count": 35,
# ...
#                         "text": "yummy😍",
#                         "timestamp": 1754496739
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🧀🧀",
#                         "timestamp": 1754231604
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 30606
#             },
#             {
#                 "caption": "✨頭文字D 30週年限定店✨\n\n頭文字D 30週年限定店登陸啟德🤩\n馬上去朝聖一下🤣\n有漫畫展品 各款精品同收藏品\n例如30週年限定杯、燈、風扇、拖鞋、咕𠱸等等\n仲有藤原豆腐店打卡位 & AE86 打卡位📷\n買滿$300可以抽埋經典賽事珍藏卡❗️\n\n🖇️頭文字 D 期間限定店\n📍啟德AIRSIDE L2中庭日期\n📆即日起至2025年8月28日\n\n#頭文字D #AE86 #藤原豆腐店 #香港打卡 #香港好去處 #打卡好去處",
#                 "comments_count": 8,
#                 "hashtags": [
#                     "頭文字D",
#                     "AE86",
#                     "藤原豆腐店",
#                     "香港打卡",
#                     "香港好去處",
#                     "打卡好去處"
#                 ],
#                 "likes_count": 2702,
#                 "mentions": [],
#                 "post_id": "3689634934089894487",
#                 "post_url": "https://www.instagram.com/p/DM0N2yNTMpX/",
#                 "timestamp": 1754058820,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "altheachanchan1212",
#                         "sentiment": "positive",
#                         "text": "👏",
#                         "timestamp": 1754129459
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "positive",
#                         "text": "🖤🖤",
#                         "timestamp": 1754061535
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "mingcheng_22",
#                         "sentiment": "positive",
#                         "text": "太有情懷了吧，頭文字D年輕時候回憶了",
#                         "timestamp": 1754135386
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hk.eatallday",
#                         "sentiment": "positive",
#                         "text": "小心甩尾啊！😂",
#                         "timestamp": 1754186626
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kenji_hkc",
#                         "sentiment": "neutral",
#                         "text": "邊度？",
#                         "timestamp": 1754141121
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "kc___________________9",
#                         "sentiment": "neutral",
#                         "text": "頭D 30年㗎喇？ 😢😮",
#                         "timestamp": 1754127658
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "angielaubaby",
#                         "sentiment": "neutral",
#                         "text": "小心甩尾呀！",
#                         "timestamp": 1754380854
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 38300
#             },
#             {
#                 "caption": "✨$168大大鍋🥘冬蔭功海鮮麵鍋🥢✨\n\n由泰國師傅主理嘅正宗泰菜🇹🇭\n點咗好多枱都必叫嘅冬蔭功鍋🥘\n底下有熱爐 keep住熱辣辣🔥\n冬蔭功湯酸酸辣辣 大約二人份量左右\n配料包括扇貝、蜆、魷魚等等\n配搭MAMA麵好惹味開胃🤪\n叫多份自選沙嗲串燒 $90有六串\n雞肉/豬肉/牛肉/豬頸肉/雞全翼/墨魚丸/司華力腸🍢\n粉絲大蝦煲有四隻大蝦🦐\n粉絲超多 塞爆咗個煲😳炒得乾身入味\n最後記得食埋甜品 七隻色嘅芒果糯米飯🥭\n砌到好似一朵花咁🌼超靚 望到都開心🥳又靚又好味\n\n冬陰功海鮮麵鍋$168\n沙嗲串燒$90/6\n粉絲大蝦煲$198\n鹹肉椰菜苗$88\n七色彩虹芒果糯米飯$88\n\n🖇️金泰子泰國餐廳\n📍太子柏樹街21號地舖\n☎️21726106\n\n#foodxtaste太子\n#太子美食 #泰國 #泰式料理 #泰國美食 #香港好去處",
#                 "comments_count": 14,
#                 "hashtags": [
#                     "foodxtaste太子",
#                     "太子美食",
#                     "泰國",
#                     "泰式料理",
#                     "泰國美食",
#                     "香港好去處"
#                 ],
#                 "likes_count": 1335,
#                 "mentions": [],
#                 "post_id": "3688096983186585104",
#                 "post_url": "https://www.instagram.com/p/DMuwKp0BrYQ/",
#                 "timestamp": 1753875706,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkeatwhatho",
#                         "sentiment": "positive",
#                         "text": "好大鍋😍",
#                         "timestamp": 1753949907
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "allebasi_nahc",
#                         "sentiment": "neutral",
#                         "text": "有冇唔辣？😮",
#                         "timestamp": 1754668599
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "hkol_foodie",
#                         "sentiment": "positive",
#                         "text": "個粉絲好正呀😍",
#                         "timestamp": 1753887428
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "foodvibes.sy",
#                         "sentiment": "positive",
#                         "text": "😍😍😍",
#                         "timestamp": 1753878140
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "tk_706",
#                         "sentiment": "positive",
#                         "text": "🤤",
#                         "timestamp": 1753935465
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hhellowing",
#                         "sentiment": "positive",
#                         "text": "@marychw715 下次一齊食",
#                         "timestamp": 1753876483
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "waiyee_13102014",
#                         "sentiment": "positive",
#                         "text": "@moeeeng 好似幾惹味",
#                         "timestamp": 1753876160
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "royng83333",
#                         "sentiment": "positive",
#                         "text": "👏🔥",
#                         "timestamp": 1753880059
#                     },
#                     {
#                         "likes_count": 4,
#                         "owner_username": "hhazelsdaily",
#                         "sentiment": "positive",
#                         "text": "😍好味",
#                         "timestamp": 1753878820
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🍜🍜",
#                         "timestamp": 1753876042
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "joanna21380",
#                         "sentiment": "neutral",
#                         "text": "How much?",
#                         "timestamp": 1753882991
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 32725
#             },
#             {
#                 "caption": "✨顛覆對健康食物嘅印象😳✨\n\n原來健康食物都可以咁好食😎\n自選形式去揀選自己嘅bowl🥣\n每款菜式都悉心配搭製作\n如泰式椰菜花 辣辣地有香料味好惹味🌶️\n紅菜頭會用士多啤梨去浸走紅菜頭嘅草青味🍓\n仲有自家製嘅素XO醬 配搭西蘭花🥦\n椰菜絲配乾蔥等等\nPROTEIN有低溫M7和牛🥩牛味香濃\n仲有刺身級數 自己片嘅煎挪威三文魚🐟\n一個飯盒可以滿足身體一日嘅營養所需❗️\n晚餐限定 低溫伊比利亞豬鞍🐽\n可以揀飯或者沙律🥗個醬汁係靈魂\n有一絲絲蟹肉🥹調味有微微辣 Yummy\n豬鞍用低溫製作 肉質軟腍好吃👍🏻\n\n1 BASE + 1 PROTEIN + 2 VEGGIES\n+ 1 SIDE + 1 SAUCE + 1 TOPPING$88up\nDinner Menu Power Chop$268\n\n🖇️Fete up @feteuphk \n📍中環康樂廣場1號怡和大廈地庫LG樓\n\n#foodxtaste中環\n#中環美食 #素食 #健康 #健康習慣 #健康餐 #gym #gymlife #gymlove",
#                 "comments_count": 13,
#                 "hashtags": [
#                     "foodxtaste中環",
#                     "中環美食",
#                     "素食",
#                     "健康",
#                     "健康習慣",
#                     "健康餐",
#                     "gym",
#                     "gymlife",
#                     "gymlove"
#                 ],
#                 "likes_count": 2489,
#                 "mentions": [
#                     "feteuphk"
#                 ],
#                 "post_id": "3687368988763143645",
#                 "post_url": "https://www.instagram.com/p/DMsKo8LBL3d/",
#                 "timestamp": 1753788600,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sophronia218",
#                         "sentiment": "positive",
#                         "text": "呢間好食😋",
#                         "timestamp": 1753887233
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkol_foodie",
#                         "sentiment": "positive",
#                         "text": "好多菜正呀😍😍",
#                         "timestamp": 1753887441
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodieyanyannn",
#                         "sentiment": "positive",
#                         "text": "呢間食過正😍",
#                         "timestamp": 1753847056
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "clement_hei",
#                         "sentiment": "negative",
#                         "text": "Openrice話中上環店已結業播",
#                         "timestamp": 1753804135
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cara_yeung",
#                         "sentiment": "positive",
#                         "text": "啱我😍",
#                         "timestamp": 1753790885
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "normifan",
#                         "sentiment": "positive",
#                         "text": "正呀喂！係邊庶？",
#                         "timestamp": 1753797735
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "luna_me",
#                         "sentiment": "negative",
#                         "text": "啱啱去完店員話冇得咁樣叫啦😢",
#                         "timestamp": 1754719713
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🥢🥢",
#                         "timestamp": 1753798713
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 61479
#             },
#             {
#                 "caption": "✨屯門新開拉麵店🍜✨\n\n試業中的拉麵店🍜\n平時有幾款口味拉麵同沾麵🥢\n今次去 咁啱係水原師傅一日限定pop up\n會製作special沾麵😙\n貝汁昆布水沾麵\n特製沾麵用咗本地食材去製作\n麵條係用九龍麵粉\n食落有韌勁 幾喜歡麵條嘅口感🤣\n沾麵湯汁 酸酸哋稍為偏鹹\n內有本地小棠菜 豬肉&蝦雲吞\n粒蝦雲吞好足料食落有薑蓉味幾特別～\n\n🖇️麵屋進化\n📍屯門青菱徑7號華興大廈地下B號舖",
#                 "comments_count": 16,
#                 "hashtags": [],
#                 "likes_count": 2522,
#                 "mentions": [],
#                 "post_id": "3686644211522041363",
#                 "post_url": "https://www.instagram.com/p/DMpl2CxBXYT/",
#                 "timestamp": 1753702200,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hkol_foodie",
#                         "sentiment": "positive",
#                         "text": "好遠但好想食呀",
#                         "timestamp": 1753887450
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodieyanyannn",
#                         "sentiment": "positive",
#                         "text": "竟然係𝐭𝐮𝐞𝐧𝐦𝐮𝐧!!",
#                         "timestamp": 1753710682
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "manvinkk",
#                         "sentiment": "neutral",
#                         "text": "我估系...烏冬麵嗰個位？😮",
#                         "timestamp": 1753721480
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "nam_wong_nam",
#                         "sentiment": "neutral",
#                         "text": "雲吞麵？",
#                         "timestamp": 1753846660
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "va12301230",
#                         "sentiment": "positive",
#                         "text": "😍",
#                         "timestamp": 1754055359
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "mygirl_yanyan0209",
#                         "sentiment": "neutral",
#                         "text": "@leung_ka_to",
#                         "timestamp": 1753719372
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "natalieakling",
#                         "sentiment": "neutral",
#                         "text": "間串燒執左？",
#                         "timestamp": 1753796022
#                     },
#                     {
#                         "likes_count": 9,
#                         "owner_username": "lolohohololohoohholohlohohohll",
#                         "sentiment": "negative",
#                         "text": "呢間會唔會好似隔離 另一間咁 當d客係狗咁樣撚架？",
#                         "timestamp": 1753706155
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ivan__lam_",
#                         "sentiment": "negative",
#                         "text": "仲貴過道拉麵",
#                         "timestamp": 1753705142
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "foodxtaste",
#                         "sentiment": "neutral",
#                         "text": "🍜🍜",
#                         "timestamp": 1753760507
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "jas.kin",
#                         "sentiment": "negative",
#                         "text": "太貴.. 不了",
#                         "timestamp": 1753702800
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "va12301230",
#                         "sentiment": "neutral",
#                         "text": "好唔好食啊？有冇邊一隻麵推介？",
#                         "timestamp": 1754055357
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "maticmum",
#                         "sentiment": "neutral",
#                         "text": "@hyleung15",
#                         "timestamp": 1753719041
#                     },
#                     {
#                         "likes_count": -1,
#                         "owner_username": "",
#                         "sentiment": "neutral",
#                         "text": "",
#                         "timestamp": ""
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 52354
#             }
#         ],
#         "username": "foodxtaste"
#     },
#     "task_type": "profile_tracking",
#     "user_id": "21774c0a-5f3a-41fe-a671-8132a4a933c5"
# }

# %% [markdown]
# ## Sentiment Analysis Summary
#
# Get a comprehensive sentiment analysis summary for your tracked profiles.

# %%
# Get sentiment summary - Select task from server immediately
print("🎯 Select a task for sentiment analysis:")
selected_task_id = smart_task_selector(auto_select_first=True)

if selected_task_id:
    print(f"\n📊 Analyzing sentiment for task: {selected_task_id}")
    sentiment_summary = get_sentiment_summary(selected_task_id)
    
    if sentiment_summary:
        print(f"📊 Sentiment Analysis Summary")
        print(f"=" * 40)
        print(f"📈 Overall Sentiment: {sentiment_summary['overall_sentiment'].upper()}")
        print(f"💬 Total Comments Analyzed: {sentiment_summary['total_comments']}")
        
        if sentiment_summary['total_comments'] > 0:
            print(f"\n📋 Sentiment Distribution:")
            for sentiment, count in sentiment_summary['sentiment_distribution'].items():
                percentage = sentiment_summary['sentiment_percentages'][sentiment]
                emoji = {'positive': '😊', 'negative': '😞', 'neutral': '😐'}[sentiment]
                print(f"   {emoji} {sentiment.capitalize()}: {count} comments ({percentage:.1f}%)")
            
            # Create a simple visual representation
            print(f"\n📊 Visual Distribution:")
            max_width = 30
            for sentiment, percentage in sentiment_summary['sentiment_percentages'].items():
                bar_width = int((percentage / 100) * max_width)
                bar = "█" * bar_width + "░" * (max_width - bar_width)
                emoji = {'positive': '😊', 'negative': '😞', 'neutral': '😐'}[sentiment]
                print(f"   {emoji} {sentiment.capitalize():8} |{bar}| {percentage:.1f}%")
        else:
            print("\n❌ No comments found to analyze.")
    else:
        print("❌ No sentiment data available. Make sure the task has been scraped.")
else:
    print("❌ No task selected or no tasks available on server.")

# %% [markdown]
# ## Compare Multiple Profiles
#
# Compare sentiment analysis across multiple tracked profiles.

# %%
# Compare sentiment across all tracked profiles - Updated to fetch fresh data from server
tasks_from_server = get_tracking_tasks()
if tasks_from_server and len(tasks_from_server) > 0:
    print("📊 Sentiment Comparison Across All Profiles")
    print("=" * 50)
    
    comparison_data = []
    
    # Get fresh task data from server instead of using cached all_task_ids
    for task in tasks_from_server:
        task_id = task['_id']
        task_details = get_task_details(task_id)
        if task_details:
            sentiment_summary = get_sentiment_summary(task_id)
            
            if sentiment_summary and sentiment_summary['total_comments'] > 0:
                comparison_data.append({
                    'Profile': f"@{task_details['target_profile']}",
                    'Type': 'Competitor' if task_details['is_competitor'] else 'Own',
                    'Overall': sentiment_summary['overall_sentiment'].title(),
                    'Positive %': f"{sentiment_summary['sentiment_percentages']['positive']:.1f}%",
                    'Negative %': f"{sentiment_summary['sentiment_percentages']['negative']:.1f}%",
                    'Neutral %': f"{sentiment_summary['sentiment_percentages']['neutral']:.1f}%",
                    'Total Comments': sentiment_summary['total_comments']
                })
    
    if comparison_data:
        comparison_df = pd.DataFrame(comparison_data)
        display(comparison_df)
        
        # Find best and worst performing profiles
        print(f"\n🏆 Analysis Insights:")
        
        own_profiles = [row for row in comparison_data if row['Type'] == 'Own']
        competitor_profiles = [row for row in comparison_data if row['Type'] == 'Competitor']
        
        if own_profiles:
            best_own = max(own_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            print(f"   🥇 Best performing own profile: {best_own['Profile']} ({best_own['Positive %']} positive)")
        
        if competitor_profiles:
            best_competitor = max(competitor_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            worst_competitor = min(competitor_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            print(f"   🎯 Best competitor: {best_competitor['Profile']} ({best_competitor['Positive %']} positive)")
            print(f"   📉 Worst competitor: {worst_competitor['Profile']} ({worst_competitor['Positive %']} positive)")
    else:
        print("❌ No sentiment data available for comparison. Make sure tasks have been scraped.")
else:
    print("❌ No tasks available for comparison. Create some tasks first using the cells above.")

# %% [markdown]
# ## 🗑️ Task Delete
#
# Let's add functionality to view and delete specific tracking tasks.

# %%
# View and Delete Specific Tasks
def view_and_delete_tasks():
    """Interactive function to view tasks and select one to delete"""
    print("📋 Your Instagram Tracking Tasks:")
    print("=" * 50)
    
    # Get all tasks
    tasks = get_tracking_tasks()
    
    if not tasks:
        print("❌ No tasks found.")
        return
    
    # Display tasks with numbers
    for i, task in enumerate(tasks, 1):
        status_emoji = "✅" if task.get("status") == "active" else "⏸️"
        competitor_text = "🏢 Competitor" if task.get("is_competitor") else "👤 Own Profile"
        
        print(f"{i}. {status_emoji} @{task['target_profile']} ({competitor_text})")
        print(f"   📅 Created: {task.get('created_at', 'Unknown')}")
        print(f"   🔄 Last Scraped: {task.get('last_scraped', 'Never')}")
        print(f"   🆔 Task ID: {task['_id']}")
        print()
    
    # Ask user to select a task to delete
    try:
        selection = input(f"Enter task number to DELETE (1-{len(tasks)}) or 'q' to quit: ").strip()
        
        if selection.lower() == 'q':
            print("👋 Operation cancelled.")
            return
        
        task_num = int(selection)
        if 1 <= task_num <= len(tasks):
            selected_task = tasks[task_num - 1]
            
            # Confirm deletion
            confirm = input(f"⚠️  Are you sure you want to DELETE @{selected_task['target_profile']}? (yes/no): ").strip().lower()
            
            if confirm in ['yes', 'y']:
                success = delete_tracking_task(selected_task['_id'])
                if success:
                    print(f"✅ Successfully deleted tracking task for @{selected_task['target_profile']}")
                else:
                    print(f"❌ Failed to delete task for @{selected_task['target_profile']}")
            else:
                print("👋 Deletion cancelled.")
        else:
            print("❌ Invalid selection. Please enter a valid task number.")
            
    except ValueError:
        print("❌ Invalid input. Please enter a number or 'q'.")
    except KeyboardInterrupt:
        print("\n👋 Operation cancelled.")

# Run the interactive task deletion
view_and_delete_tasks()

# %% [markdown]
# ## ⚠️ Account Deletion
#
# **WARNING**: This will permanently delete the demo account and ALL associated data, including Instagram tracking tasks!

# %%
# Delete Demo Account (USE WITH CAUTION!)
def delete_demo_account():
    """Delete the demo account and all associated data"""
    print("⚠️  ACCOUNT DELETION WARNING ⚠️")
    print("=" * 50)
    print("This action will PERMANENTLY DELETE:")
    print("• The demo user account")
    print("• ALL Instagram tracking tasks")
    print("• ALL associated data")
    print("• This action CANNOT be undone!")
    print("=" * 50)
    
    try:
        # First confirmation
        confirm1 = input("Type 'DELETE' to continue or anything else to cancel: ").strip()
        
        if confirm1 != 'DELETE':
            print("👋 Account deletion cancelled.")
            return
        
        # Second confirmation with email
        current_email = "ig_tracking_test@email.com"  # The demo account email
        confirm2 = input(f"Type the email '{current_email}' to confirm: ").strip()
        
        if confirm2 != current_email:
            print("❌ Email confirmation failed. Account deletion cancelled.")
            return
        
        # Proceed with deletion
        print("\n🗑️  Deleting account...")
        success = client.delete_account()
        
        if success:
            print("✅ Demo account successfully deleted!")
            print("📋 All Instagram tracking tasks have been removed.")
            print("🔒 Session token invalidated.")
            print("\n👋 Thank you for trying the Instagram Tracking Service!")
            
            # Clear the session token
            client.session_token = None
        else:
            print("❌ Failed to delete account. Please try again or contact support.")
            
    except KeyboardInterrupt:
        print("\n👋 Account deletion cancelled.")

delete_demo_account()
