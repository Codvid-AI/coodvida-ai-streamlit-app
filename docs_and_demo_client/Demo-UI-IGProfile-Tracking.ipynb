# %% [markdown]
# # Instagram Tracking Service Demo
#
# This notebook demonstrates how to use the Instagram tracking service to:
# - Create tracking tasks for Instagram profiles
# - Monitor both your own profiles and competitors
# - Analyze sentiment from comments
# - View tracking results and statistics
#
# ## Prerequisites
# - Valid user account (signup/login)
# - Instagram usernames to track
# - Server running with Instagram tracking service enabled

# %% [markdown]
# ## ◈ Initialization and Login

# %%
# set account
email = "ig_tracking_test@email.com"
password = "12345"





### Import required modules
from demo_modules import client, network
import json
from IPython.display import display, HTML, clear_output
import pandas as pd


client.init(
    "local"
)  # Change to "production" or "local" as needed for different base urls
print("✓ Client initialized successfully")


### Login (or signup if you don't have an account)
client.signup(email, password)  # will affect nothing if exist
success = client.login(email, password)

if success:
    print("✓ Login successful!")
else:
    print("❌ Login failed. Trying to signup...")
    # If login fails, try to signup
    success = client.signup(email, password)
    if success:
        print("✓ Signup successful! You are now logged in.")
    else:
        print("❌ Signup failed. Please check your credentials.")

print(f"Session token: {'✓ Available' if client.session_token else '❌ Not available'}")
# Out:
# Using base URL: http://localhost:8080
# ✓ Client initialized successfully
# Sending POST JSON: {"schema_version": "4.0", "data": {"auth_type": "email", "email": "ig_tracking_test@email.com", "password": "12345"}}
# - Status Code: 400
# - Response (json):
# {
#     "message": "Email is already linked to an account",
#     "result": false
# }
#
# Sending POST JSON: {"schema_version": "4.0", "data": {"auth_type": "email", "email": "ig_tracking_test@email.com", "password": "12345"}}
# - Status Code: 201
# - Response (json):
# {
#     "result": true,
#     "token": "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJjNmEyYWYwNC05OGU4LTRmYjYtYTM4Yi1iM2UyNzU4NTFhNzYiLCJleHAiOjE3NTcyNTYzMzUuNDkyODMxfQ.Cav3DRl_O8Zz1bQT8hf4a5lCRiQQE1vCSgPLURmd1zI"
# }
#
# ✓ Login successful!
# Session token: ✓ Available

# %% [markdown]
# ## ◈ Instagram Tracking Functions Declaration
#
# Let's create helper functions to interact with the Instagram tracking API.

# %%
from demo_modules.ig_tracking_functions import *
# Out:
# ✓ Instagram tracking functions loaded
# ✓ Smart task selector function loaded

# %%
# new functions

def update_scrape_interval_task(task_id: str, new_interval_days: float):
    """Update the scrape interval for an existing tracking task"""
    print(f"🔄 Updating scrape interval for task {task_id} to {new_interval_days} days...")
    response = network.send(
        f"/codvid-ai/ig-tracking/update_scrape_interval/{task_id}",
        content={
            "scrape_interval_days": new_interval_days
        },
        session_token=client.session_token,
        method="PUT"
    )
    
    result = response.get_dict()
    if result and result.get("result"):
        print("✓ Scrape interval updated successfully!")
        return True
    else:
        print(f"❌ Failed to update scrape interval: {result.get('message', 'Unknown error') if result else 'No response'}")
        return False

# %% [markdown]
# ## 👀 View Tracking Tasks
#
# Let's see all the tracking tasks you have created.

# %%
# Get all tracking tasks
tasks = get_tracking_tasks()

def select_task_from_server():
    """Interactive function to select a task from server"""
    server_tasks = get_tracking_tasks()
    if not server_tasks or len(server_tasks) == 0:
        print("❌ No tasks found on server.")
        return None
    
    print("Available Instagram Tracking Tasks:")
    for idx, task in enumerate(server_tasks):
        profile = task.get('target_profile', 'unknown')
        ttype = 'Competitor' if task.get('is_competitor') else 'Own Profile'
        status = task.get('status', 'unknown')
        last_scraped = task.get('last_scraped', 'Never')
        print(f"  {idx+1}. @{profile} ({ttype}, status: {status})")
        print(f"      Last scraped: {last_scraped}")
        print(f"      Task ID: {task.get('_id', 'N/A')}")
        print()
    
    try:
        selection = int(input(f"Select a task by number (1-{len(server_tasks)}): "))
        if 1 <= selection <= len(server_tasks):
            selected_task = server_tasks[selection-1]
            selected_task_id = selected_task.get('_id')
            print(f"✅ Selected: @{selected_task.get('target_profile')} (Task ID: {selected_task_id})")
            return selected_task_id
        else:
            print("❌ Invalid selection.")
            return None
    except (ValueError, KeyboardInterrupt):
        print("❌ Invalid input or cancelled.")
        return None

if tasks:
    # Display tasks in a nice table format
    df = pd.DataFrame(tasks)
    df['type'] = df['is_competitor'].apply(lambda x: 'Competitor' if x else 'Own Profile')
    df['last_scraped'] = df['last_scraped'].fillna('Never')

    # Select columns to display
    display_df = df[['target_profile', 'type', 'status', 'last_scraped', 'next_scrape_due']].copy()
    display_df.columns = ['Instagram Profile', 'Type', 'Status', 'Last Scraped', 'Next Scrape Due']

    print("📊 Your Instagram Tracking Tasks:")
    display(display_df)

    # Store task IDs for later use
    all_task_ids = df['_id'].tolist()
    print(f"\n📋 Total tasks: {len(all_task_ids)}")
# Out:
# ✓ Found 2 tracking tasks
# 📊 Your Instagram Tracking Tasks:
#   Instagram Profile         Type  Status Last Scraped  Next Scrape Due
# 0         pomatohhk  Own Profile  active        Never       1754837319
# 1  trialanderror924   Competitor  active        Never       1754837319
# 📋 Total tasks: 2

# %% [markdown]
# ## ➕ Create Tracking Tasks
#
# Let's create some tracking tasks for Instagram profiles. You can track both your own profiles and competitors.

# %%
# Create a tracking task for your own profile
if input("Enter [y] to confirm create:") == "y":
    profile = "pomatohk"  # Replace with your actual username
    task_id_own = create_tracking_task(profile, is_competitor=False)
    
    profile = "trialanderror924"  # Replace with your actual username
    task_id_own = create_tracking_task(profile, is_competitor=True)
else:
    print("cancelled")
    
# own_profile = "foodxtaste"  # Replace with your actual username
# task_id_own = create_tracking_task(own_profile, is_competitor=False)

# # Track a competitor
# competitor_profile = "joeie_foodie"  # Replace with competitor's username
# task_id_competitor = create_tracking_task(competitor_profile, is_competitor=True)
# Out:
# Sending POST JSON: {"schema_version": "4.0", "data": {"target_profile": "pomatohk", "is_competitor": false}}
# ✓ Created tracking task for @pomatohk
#   Task ID: bb1e55ba-6783-4568-86e2-b10544bb4782
#   Type: Own Profile
# Sending POST JSON: {"schema_version": "4.0", "data": {"target_profile": "trialanderror924", "is_competitor": true}}
# ✓ Created tracking task for @trialanderror924
#   Task ID: 2a9d0d76-a02e-4203-bafc-004bbadd72ee
#   Type: Competitor

# %% [markdown]
# ## ⏰ Update Scrape Interval
#
# You can adjust the scraping frequency for an existing tracking task.

# %%
# Select a task to update its scrape interval
selected_task_id_for_update = smart_task_selector()

if selected_task_id_for_update:
    try:
        new_interval = float(input("Enter new scrape interval in days (float): "))
        print(new_interval, new_interval>0)
        if new_interval > 0:
            update_scrape_interval_task(selected_task_id_for_update, new_interval)
            print("💡 After updating, you can view tasks again to see the new 'Next Scrape Due' date.")
        else:
            print("❌ Invalid interval. Please enter a positive integer.")
    except ValueError:
        print("❌ Invalid input. Please enter a number.")
else:
    print("❌ No task selected for update.")
# Out:
# ✓ Found 2 tracking tasks
# 🎯 Select a task from server:
# ----------------------------------------
#   1. @pomatohhk (Own Profile)
#       Status: active, Last scraped: None
#   2. @trialanderror924 (Competitor)
#       Status: active, Last scraped: None
# ✅ Selected: @pomatohhk (ID: f1e0bad2-6568-4b75-a1fe-e97fbaae141a)
# ❌ Invalid input. Please enter a number.

# %% [markdown]
# ## 🐎 Force Scrape a Task
#
# You can manually trigger scraping for any task. This will fetch the latest posts and analyze comments.

# %%
# Fetch latest tasks from server and let user select one
selected_task_id = smart_task_selector()

print(f"🎯 Selected task: {selected_task_id}")

# Get task details before scraping
task_details = get_task_details(selected_task_id)
if task_details:
    print(f"📱 Profile: @{task_details['target_profile']}")
    print(f"📊 Type: {'Competitor' if task_details['is_competitor'] else 'Own Profile'}")
    print(f"📅 Last scraped: {task_details.get('last_scraped', 'Never')}")
    
    # Force scrape
    success = force_scrape_task(selected_task_id)
    
    if success:
        print("💡 Done! Run the next cell to view the results after scraping completes.")
    else:
        print("❌ Scraping failed to initiate.")
else:
    print("❌ Could not get task details.")
# Out:
# ✓ Found 2 tracking tasks
# 🎯 Select a task from server:
# ----------------------------------------
#   1. @pomatohk (Own Profile)
#       Status: active, Last scraped: None
#   2. @trialanderror924 (Competitor)
#       Status: active, Last scraped: None
# ✅ Selected: @pomatohk (ID: bb1e55ba-6783-4568-86e2-b10544bb4782)
# 🎯 Selected task: bb1e55ba-6783-4568-86e2-b10544bb4782
# 📱 Profile: @pomatohk
# 📊 Type: Own Profile
# 📅 Last scraped: None
# 🔄 Initiating scrape for task bb1e55ba-6783-4568-86e2-b10544bb4782...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 14
#      11 print(f"📅 Last scraped: {task_details.get('last_scraped', 'Never')}")
#      13 # Force scrape
# ---> 14 success = force_scrape_task(selected_task_id)
#      16 if success:
#      17     print("💡 Done! Run the next cell to view the results after scraping completes.")
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/NOTEBOOKS/demo_client/demo_modules/ig_tracking_functions.py:64, in force_scrape_task(task_id)
#      62 """Force immediate scraping of a tracking task"""
#      63 print(f"🔄 Initiating scrape for task {task_id}...")
# ---> 64 response = network.send(
#      65     f"/codvid-ai/ig-tracking/force_scrape/{task_id}",
#      66     session_token=client.session_token,
#      67     method="POST"  # Correct: Use POST method
#      68 )
#      70 result = response.get_dict()
#      71 if result and result.get("result"):
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/NOTEBOOKS/demo_client/demo_modules/network.py:88, in send(route, content, session_token, method, stream, verify_ssl)
#      85 # ----- normal send -----
#      86 else:
#      87     try:
# ---> 88         response = requests.request(
#      89             method, url, headers=headers, data=json_str if data else None, verify=verify_ssl
#      90         )
#      92         status_code = response.status_code
#      93         result = RequestResult(response.text, status_code, exception=None)
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/_Keeps_/Coding Space/Projects/codvid-ai/codvid-ai-backend/.venv/lib/python3.10/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ## 📖 View Task Details
#
# Let's examine the detailed results from a scraped task, including posts and comments.

# %%
# Select Task
all_tasks = get_tracking_tasks()
if all_tasks and isinstance(all_tasks, list) and len(all_tasks) > 0:
    print("Available Instagram Tracking Tasks:")
    for idx, task in enumerate(all_tasks):
        profile = task.get('target_profile', 'unknown')
        ttype = 'Competitor' if task.get('is_competitor') else 'Own Profile'
        status = task.get('status', 'unknown')
        print(f"  {idx+1}. @{profile} ({ttype}, status: {status}) [Task ID: {task.get('_id', 'N/A')}]")
    try:
        selection = int(input(f"\nSelect a task by number (1-{len(all_tasks)}): "))
        if 1 <= selection <= len(all_tasks):
            selected_task_id = all_tasks[selection-1]['_id']
        else:
            print("❌ Invalid selection.")
            selected_task_id = None
    except Exception as e:
        print("❌ Invalid input:", e)
        selected_task_id = None
else:
    print("❌ No tasks available on server. Create some tasks first!")
    selected_task_id = None

# Get detailed results for the selected task
if selected_task_id:
    task_details = get_task_details(selected_task_id)
    
    if task_details:
        print(json.dumps(task_details, indent=4, ensure_ascii=False))
    else:
        print("❌ No scraped data available. Try running the force scrape cell first and wait for completion.")
else:
    print("❌ No task selected.")
# Out:
# ✓ Found 2 tracking tasks
# Available Instagram Tracking Tasks:
#   1. @pomatohk (Own Profile, status: active) [Task ID: bb1e55ba-6783-4568-86e2-b10544bb4782]
#   2. @trialanderror924 (Competitor, status: active) [Task ID: 2a9d0d76-a02e-4203-bafc-004bbadd72ee]
# {
#     "_id": "bb1e55ba-6783-4568-86e2-b10544bb4782",
#     "created_at": 1754664707,
#     "is_competitor": false,
#     "last_scraped": 1754665548,
#     "next_scrape_due": 1754838348,
#     "schema_version": "1.3",
#     "scrape_interval_days": 2,
#     "status": "active",
#     "target_profile": "pomatohk",
#     "target_profile_data": {
#         "biography": "由簡單創出不平凡 🍅🥔\nFacebook/YouTube: Pomato 小薯茄\nFacebook group:蕃茄薯仔湯\n粉絲信箱：荃灣郵政局郵政信箱1486號\nPO BOX 1486, Tsuen Wan Post Office, Hong Kong (不需加上收件人)",
#         "followers": 729752,
#         "following": 41,
#         "full_name": "Pomato 小薯茄",
#         "icon_pic_url": "https://scontent-iad3-2.cdninstagram.com/v/t51.2885-19/249486828_422675936139371_2241007389797742511_n.jpg?stp=dst-jpg_s320x320_tt6&efg=eyJ2ZW5jb2RlX3RhZyI6InByb2ZpbGVfcGljLmRqYW5nby4xMDgwLmMyIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=111&_nc_oc=Q6cZ2QGeXea0upzqoWP2EffQWTBlE6ig9OVFkzVKvq5uxrynjXjm8CnbBcVmFV_SkSlKwxM&_nc_ohc=TYbC0-0pw-IQ7kNvwF0lUdY&_nc_gid=3FWv6qs8kCP8_3uPPvQ67w&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AfUo0O1QmhkbkbsX9dywqD2IdV6vbDRCLl0qK-ahaBDS2A&oe=689BC8E7&_nc_sid=8b3546",
#         "ig_tv_video_count": 408,
#         "posts_count": 2411,
#         "scraped_posts": [
#             {
#                 "caption": "【雪櫃冷笑話#556】\n係放煙花唔會射到星星嘅故事 \n感謝麗英分享笑話一則\n@laiyingdesu @tungtungdess\n\n麗英出新歌喇！〈命中注定在一起〉👫🏻\n大家快啲去麗英 LaiYing YouTube 睇MV！\n同埋快啲去各大音樂平台收聽啦！ 🎧\n\n#雪櫃冷笑話 #第五百五十六集 #小薯茄 #笑咗請留言 #爛Gag #冷笑話 #歡迎投稿 #命中注定在一起 #pomato",
#                 "comments_count": 20,
#                 "hashtags": [
#                     "556】",
#                     "雪櫃冷笑話",
#                     "第五百五十六集",
#                     "小薯茄",
#                     "笑咗請留言",
#                     "爛Gag",
#                     "冷笑話",
#                     "歡迎投稿",
#                     "命中注定在一起",
#                     "pomato"
#                 ],
#                 "likes_count": 2490,
#                 "mentions": [
#                     "laiyingdesu",
#                     "tungtungdess"
#                 ],
#                 "post_id": "3694647059109124562",
#                 "post_url": "https://www.instagram.com/p/DNGBezYpBnS/",
#                 "timestamp": 1754656295,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winson_hui",
#                         "sentiment": "positive",
#                         "text": "😍😍😍",
#                         "timestamp": 1754662612
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "yiurs._pu",
#                         "sentiment": "positive",
#                         "text": "🔥🔥🔥",
#                         "timestamp": 1754656499
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "hoit__y",
#                         "sentiment": "positive",
#                         "text": "🤣🤣",
#                         "timestamp": 1754656443
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "dennisyau507",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1754656741
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "heison.cyh_1103",
#                         "sentiment": "neutral",
#                         "text": "起碼10年前嘅笑話😂",
#                         "timestamp": 1754656992
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "chloe_cheng_029",
#                         "sentiment": "positive",
#                         "text": "英童！💗💚",
#                         "timestamp": 1754656559
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "wailokoap",
#                         "sentiment": "positive",
#                         "text": "😂😂😂 比🖐分",
#                         "timestamp": 1754658814
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "stephenchancc",
#                         "sentiment": "neutral",
#                         "text": "雪櫃老笑話😂",
#                         "timestamp": 1754663967
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "rainsome_vincent",
#                         "sentiment": "positive",
#                         "text": "咁舊嘅笑話全靠麗英肢體顏藝救返",
#                         "timestamp": 1754657987
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winnieee_.13",
#                         "sentiment": "positive",
#                         "text": "咁英童識唔識閃🔥",
#                         "timestamp": 1754657089
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "brian.nz.418",
#                         "sentiment": "positive",
#                         "text": "童B 💚",
#                         "timestamp": 1754657968
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "laiying.fan",
#                         "sentiment": "positive",
#                         "text": "呢個幾好🤣",
#                         "timestamp": 1754656750
#                     },
#                     {
#                         "likes_count": 14,
#                         "owner_username": "wanderundwandern",
#                         "sentiment": "negative",
#                         "text": "史前嘅笑話",
#                         "timestamp": 1754656627
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "naicha0726",
#                         "sentiment": "neutral",
#                         "text": "呢個OK窩",
#                         "timestamp": 1754656851
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "_collar_lt_bm_katseye28gf_",
#                         "sentiment": "neutral",
#                         "text": "呢個笑話好耐啦，唔收貨!!😂😂",
#                         "timestamp": 1754657273
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "leo.l.f.wong",
#                         "sentiment": "neutral",
#                         "text": "懷疑童童想講 你收嗲啦",
#                         "timestamp": 1754661090
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "n1a2u3iiik",
#                         "sentiment": "negative",
#                         "text": "大家都知個笑點唔喺個笑話度😢",
#                         "timestamp": 1754659704
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lilylee8533",
#                         "sentiment": "positive",
#                         "text": "😂",
#                         "timestamp": 1754658456
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ry8502_6688",
#                         "sentiment": "positive",
#                         "text": "童童😍😍😍😍",
#                         "timestamp": 1754658366
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "emil20031234",
#                         "sentiment": "neutral",
#                         "text": "3分",
#                         "timestamp": 1754656775
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 12709
#             },
#             {
#                 "caption": "【雪櫃冷笑話#555】\n係龜兔賽跑再賽跑嘅故事\n感謝江若琳分享笑話一則\n@elannek930  @chumichael \n\n江若琳「The Witness 心的見證演唱會2025」✨\n時間：8月24日 8:00pm\n地點：旺角麥花臣場館\n\n#雪櫃冷笑話 #第五百五十五集 #小薯茄 #笑咗請留言 #爛Gag #冷笑話 #歡迎投稿 #pomato",
#                 "comments_count": 48,
#                 "hashtags": [
#                     "555】",
#                     "雪櫃冷笑話",
#                     "第五百五十五集",
#                     "小薯茄",
#                     "笑咗請留言",
#                     "爛Gag",
#                     "冷笑話",
#                     "歡迎投稿",
#                     "pomato"
#                 ],
#                 "likes_count": 3040,
#                 "mentions": [
#                     "elannek930",
#                     "chumichael"
#                 ],
#                 "post_id": "3692472445973321646",
#                 "post_url": "https://www.instagram.com/p/DM-TCBFKFeu/",
#                 "timestamp": 1754397064,
#                 "top_comments": [
#                     {
#                         "likes_count": 2,
#                         "owner_username": "elannek930",
#                         "sentiment": "positive",
#                         "text": "😂😂😂😂😂❤️",
#                         "timestamp": 1754399253
#                     },
#                     {
#                         "likes_count": 27,
#                         "owner_username": "calvin.notadesign",
#                         "sentiment": "neutral",
#                         "text": "堅冷😂",
#                         "timestamp": 1754397309
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cecik",
#                         "sentiment": "neutral",
#                         "text": "著晒褸先開嚟睇都仲係冷親😂😂😂",
#                         "timestamp": 1754400103
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "_monicalau_",
#                         "sentiment": "positive",
#                         "text": "喂呀 @elannek930 \n你又唱得，搞笑又得😂",
#                         "timestamp": 1754401914
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "bujaii3o6",
#                         "sentiment": "positive",
#                         "text": "牙富好俾面😂😂😂",
#                         "timestamp": 1754403565
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "nickyau1988",
#                         "sentiment": "positive",
#                         "text": "江若琳灣好笑啲😂",
#                         "timestamp": 1754608194
#                     },
#                     {
#                         "likes_count": 4,
#                         "owner_username": "codybabe",
#                         "sentiment": "positive",
#                         "text": "你真係好好笑呀 有幽默又靚女。去邊度搵啊？❤️",
#                         "timestamp": 1754401073
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "rainsome_vincent",
#                         "sentiment": "positive",
#                         "text": "多謝江若琳將舊笑話傳承比新一代🤭",
#                         "timestamp": 1754401872
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "highking",
#                         "sentiment": "neutral",
#                         "text": "我同成哥鬥資產，我贏咗，因為係鬥少呀👉",
#                         "timestamp": 1754433931
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "cherriechau",
#                         "sentiment": "positive",
#                         "text": "你幾時去開棟篤笑？",
#                         "timestamp": 1754414447
#                     },
#                     {
#                         "likes_count": 9,
#                         "owner_username": "dcking_lol",
#                         "sentiment": "neutral",
#                         "text": "自己講完自己掩面😂😂😂",
#                         "timestamp": 1754399559
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "graverhk",
#                         "sentiment": "neutral",
#                         "text": "我以為比賽游水😂",
#                         "timestamp": 1754401113
#                     },
#                     {
#                         "likes_count": 9,
#                         "owner_username": "samman9426",
#                         "sentiment": "neutral",
#                         "text": "我以為係鬥快返到自己屋企添",
#                         "timestamp": 1754399343
#                     },
#                     {
#                         "likes_count": 8,
#                         "owner_username": "tik_chung",
#                         "sentiment": "neutral",
#                         "text": "仲以為係因為隻兔仔一直「停留於 迴旋處」",
#                         "timestamp": 1754405735
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "lapming1992",
#                         "sentiment": "neutral",
#                         "text": "Wow, that’s and",
#                         "timestamp": 1754449674
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "dotdotartroom",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1754472943
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "minecopper",
#                         "sentiment": "neutral",
#                         "text": "以為係話今次鬥游水😂",
#                         "timestamp": 1754459371
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1754412404
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "fatboy7768",
#                         "sentiment": "neutral",
#                         "text": "好老尷😂",
#                         "timestamp": 1754403650
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "chs.jckwong",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1754402178
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kingkazt",
#                         "sentiment": "positive",
#                         "text": "🤣🤣🤣🐢🐢🐢",
#                         "timestamp": 1754400794
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "edwu0100",
#                         "sentiment": "negative",
#                         "text": "冰格級別",
#                         "timestamp": 1754399601
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "neutral",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1754398156
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "emil20031234",
#                         "sentiment": "negative",
#                         "text": "1分",
#                         "timestamp": 1754397867
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "louislcs",
#                         "sentiment": "neutral",
#                         "text": "兔仔：全靠你教我...",
#                         "timestamp": 1754397447
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 34234
#             },
#             {
#                 "caption": "薯茄mini game #24 跑新聞！\n跑得快有得打人！\n@elannek930 @chumichael  @fatman_yiu @jefferykwan\n\n江若琳「The Witness 心的見證演唱會2025」✨\n時間：8月24日 8:00pm\n地點：旺角麥花臣場館\n\n想睇我哋玩咩小遊戲就留言同我哋講啦！\n#minigame  #江若琳 #演唱會 #挑戰 #challenge #小遊戲 #小薯茄 #pomato #薯茄minigame",
#                 "comments_count": 37,
#                 "hashtags": [
#                     "24",
#                     "minigame",
#                     "江若琳",
#                     "演唱會",
#                     "挑戰",
#                     "challenge",
#                     "小遊戲",
#                     "小薯茄",
#                     "pomato",
#                     "薯茄minigame"
#                 ],
#                 "likes_count": 5662,
#                 "mentions": [
#                     "elannek930",
#                     "chumichael",
#                     "fatman_yiu",
#                     "jefferykwan"
#                 ],
#                 "post_id": "3691673078863424543",
#                 "post_url": "https://www.instagram.com/p/DM7dRschuwf/",
#                 "timestamp": 1754301785,
#                 "top_comments": [
#                     {
#                         "likes_count": 21,
#                         "owner_username": "deer_chupa_chups",
#                         "sentiment": "neutral",
#                         "text": "朱mic借啲易抱嘉賓，之後又放盡水😂",
#                         "timestamp": 1754303954
#                     },
#                     {
#                         "likes_count": 105,
#                         "owner_username": "litszhomichaels",
#                         "sentiment": "positive",
#                         "text": "朱Mic 好gentle",
#                         "timestamp": 1754301961
#                     },
#                     {
#                         "likes_count": 94,
#                         "owner_username": "siu.mor",
#                         "sentiment": "neutral",
#                         "text": "朱咪讓賽太明顯😏",
#                         "timestamp": 1754302246
#                     },
#                     {
#                         "likes_count": 36,
#                         "owner_username": "sindypanda",
#                         "sentiment": "neutral",
#                         "text": "朱mic遲咗幾秒先開始😂",
#                         "timestamp": 1754303710
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "mark__kwan",
#                         "sentiment": "positive",
#                         "text": "J哥好紳士，他快少少可以打落去，選擇放在中間擋",
#                         "timestamp": 1754320340
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "carriekau",
#                         "sentiment": "positive",
#                         "text": "8.24 見🤗🤗🤗",
#                         "timestamp": 1754302598
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "yau_uu_",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1754301974
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "jamie_gi",
#                         "sentiment": "positive",
#                         "text": "好好玩咁🤣好想快啲8.24🥳",
#                         "timestamp": 1754326432
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "bujaii3o6",
#                         "sentiment": "positive",
#                         "text": "大癲🥹",
#                         "timestamp": 1754303953
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "chung_alvin",
#                         "sentiment": "positive",
#                         "text": "Nice",
#                         "timestamp": 1754306855
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "elannek_fansclub",
#                         "sentiment": "positive",
#                         "text": "😂😂💙💙",
#                         "timestamp": 1754305386
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "seasonlam_",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1754313860
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "_monicalau_",
#                         "sentiment": "positive",
#                         "text": "😍😍😍😍係我最愛嘅江ling!",
#                         "timestamp": 1754302792
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "kaley122117",
#                         "sentiment": "positive",
#                         "text": "😂",
#                         "timestamp": 1754301878
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "javiswproduction",
#                         "sentiment": "neutral",
#                         "text": "會唔會有雪櫃冷笑話？唔知會NG幾多次呢😜",
#                         "timestamp": 1754326760
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "_.slxys._",
#                         "sentiment": "positive",
#                         "text": "✨️🫶🏻",
#                         "timestamp": 1754387225
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1754327382
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "kingkazt",
#                         "sentiment": "positive",
#                         "text": "KO ! 🤣🤣🤣",
#                         "timestamp": 1754306990
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "neutral",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1754304224
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cecik",
#                         "sentiment": "positive",
#                         "text": "😂😂😂😂",
#                         "timestamp": 1754303435
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "__chi8",
#                         "sentiment": "neutral",
#                         "text": "Comment",
#                         "timestamp": 1754303156
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "bb.dordor",
#                         "sentiment": "neutral",
#                         "text": "Share",
#                         "timestamp": 1754302829
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cherriechau",
#                         "sentiment": "neutral",
#                         "text": "Like",
#                         "timestamp": 1754302796
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "siupongoscar",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1754302527
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 60372
#             },
#             {
#                 "caption": "【尷到唔敢睇】\n童童同衛詩雅回憶當日拍攝，六年前《掃毒2》宣傳合作舊片重溫！\n\n快啲上小薯茄日常Pomato Daily睇片啦！\n\n#Pomato #小薯茄 #掃毒 #掃毒2 #舊片",
#                 "comments_count": 7,
#                 "hashtags": [
#                     "Pomato",
#                     "小薯茄",
#                     "掃毒",
#                     "掃毒2",
#                     "舊片"
#                 ],
#                 "likes_count": 9442,
#                 "mentions": [],
#                 "post_id": "3690328324103306794",
#                 "post_url": "https://www.instagram.com/p/DM2rg7-vX4q/",
#                 "timestamp": 1754141461,
#                 "top_comments": [
#                     {
#                         "likes_count": 1,
#                         "owner_username": "yau_uu_",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1754142009
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "jomugjei",
#                         "sentiment": "positive",
#                         "text": "❤️ig 快過 yt",
#                         "timestamp": 1754142804
#                     },
#                     {
#                         "likes_count": 10,
#                         "owner_username": "angel2014_is_am",
#                         "sentiment": "neutral",
#                         "text": "係衛詩雅呀",
#                         "timestamp": 1754143024
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "vickyleung2",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1754142059
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1754158831
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "brian.nz.418",
#                         "sentiment": "negative",
#                         "text": "六年後童童都肥咗😂💚\n童童 Sor… 🥹",
#                         "timestamp": 1754141753
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "neutral",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1754144603
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 137092
#             },
#             {
#                 "caption": "挑戰劣食！！真係食到嘔呀！🤢🤢\n多謝Michelle同我哋玩完都做到朋友😂😂\n@michellewsn @tungtungdess @jefferykwan @fatman_yiu \n\n#劣食 #鯡魚罐頭 #印度芒果醬 #液體麵包",
#                 "comments_count": 20,
#                 "hashtags": [
#                     "劣食",
#                     "鯡魚罐頭",
#                     "印度芒果醬",
#                     "液體麵包"
#                 ],
#                 "likes_count": 5988,
#                 "mentions": [
#                     "michellewsn",
#                     "tungtungdess",
#                     "jefferykwan",
#                     "fatman_yiu"
#                 ],
#                 "post_id": "3688824019887021490",
#                 "post_url": "https://www.instagram.com/p/DMxVebgS12y/",
#                 "timestamp": 1753962445,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winson_hui",
#                         "sentiment": "positive",
#                         "text": "😍😍😍😍",
#                         "timestamp": 1753976172
#                     },
#                     {
#                         "likes_count": 23,
#                         "owner_username": "lokw217",
#                         "sentiment": "negative",
#                         "text": "做乜咁睇唔開喺室內打開佢…😂",
#                         "timestamp": 1753975905
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "yau_uu_",
#                         "sentiment": "neutral",
#                         "text": "17秒！，",
#                         "timestamp": 1753962475
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "felixxxzz",
#                         "sentiment": "neutral",
#                         "text": "要浸係水入面開😂同室外",
#                         "timestamp": 1753991904
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "brian.nz.418",
#                         "sentiment": "positive",
#                         "text": "靚蔡💚",
#                         "timestamp": 1753962642
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "michelle_tang0616",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1754010138
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ivan3778",
#                         "sentiment": "positive",
#                         "text": "童童世一🔥",
#                         "timestamp": 1754008592
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "tiffanyder",
#                         "sentiment": "neutral",
#                         "text": "想問問衛詩雅條褲係咩褲子？",
#                         "timestamp": 1753983463
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ry8502_6688",
#                         "sentiment": "positive",
#                         "text": "靚蔡😍😍😍😍😍😍",
#                         "timestamp": 1753964193
#                     },
#                     {
#                         "likes_count": 12,
#                         "owner_username": "samxjones_dk6695",
#                         "sentiment": "negative",
#                         "text": "難得請影后上studio 竟然好玩唔玩，玩發酵罐頭魚？",
#                         "timestamp": 1753965389
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "mark__kwan",
#                         "sentiment": "neutral",
#                         "text": "有冇人發現最近少左呀冰出現，唔知忙咩",
#                         "timestamp": 1754024103
#                     },
#                     {
#                         "likes_count": 12,
#                         "owner_username": "miso_my_cat",
#                         "sentiment": "negative",
#                         "text": "生化危機",
#                         "timestamp": 1753962636
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "zakualive",
#                         "sentiment": "negative",
#                         "text": "好玩唔玩，喺室內玩生化武器😂",
#                         "timestamp": 1754238902
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "freddyyc2013",
#                         "sentiment": "neutral",
#                         "text": "竟然夠膽開鯡魚罐頭😂",
#                         "timestamp": 1753967593
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1753981487
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "cannyyuyu",
#                         "sentiment": "negative",
#                         "text": "臭魚😂😂😂",
#                         "timestamp": 1754038428
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "henrychiu2024",
#                         "sentiment": "positive",
#                         "text": "童童 ❤️",
#                         "timestamp": 1753978759
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "raygod99",
#                         "sentiment": "negative",
#                         "text": "呢啲唔係劣食，係化學武器",
#                         "timestamp": 1753963113
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "neutral",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1753962810
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 73918
#             },
#             {
#                 "caption": "【雪櫃冷笑話#554】\n係小明覺得自己係長頸鹿嘅故事 \n感謝衛詩雅分享笑話一則\n@michellewsn @fatman_yiu\n#雪櫃冷笑話 #第五百五十四集 #小薯茄 #笑咗請留言 #爛Gag #冷笑話 #歡迎投稿 #pomato",
#                 "comments_count": 49,
#                 "hashtags": [
#                     "554】",
#                     "雪櫃冷笑話",
#                     "第五百五十四集",
#                     "小薯茄",
#                     "笑咗請留言",
#                     "爛Gag",
#                     "冷笑話",
#                     "歡迎投稿",
#                     "pomato"
#                 ],
#                 "likes_count": 6453,
#                 "mentions": [
#                     "michellewsn",
#                     "fatman_yiu"
#                 ],
#                 "post_id": "3688048192026150398",
#                 "post_url": "https://www.instagram.com/p/DMulEpgPYX-/",
#                 "timestamp": 1753869647,
#                 "top_comments": [
#                     {
#                         "likes_count": 54,
#                         "owner_username": "rickliuau",
#                         "sentiment": "negative",
#                         "text": "唔明。。。。。。",
#                         "timestamp": 1753872443
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "ersousaskl",
#                         "sentiment": "negative",
#                         "text": "😂冷是夠的 笑話部分差啲",
#                         "timestamp": 1753953053
#                     },
#                     {
#                         "likes_count": 8,
#                         "owner_username": "wjoe1980",
#                         "sentiment": "neutral",
#                         "text": "咁幾時開始覺得係小長頸鹿😮",
#                         "timestamp": 1753871541
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "henrychiu2024",
#                         "sentiment": "positive",
#                         "text": "童童表情好cute❤️",
#                         "timestamp": 1753870268
#                     },
#                     {
#                         "likes_count": 187,
#                         "owner_username": "winvnie",
#                         "sentiment": "neutral",
#                         "text": "其實小明真係好忙😂😂\n佢要兼顧好多嘢，乜嘢都關佢事🤣🤣",
#                         "timestamp": 1753869872
#                     },
#                     {
#                         "likes_count": 13,
#                         "owner_username": "jiu7251",
#                         "sentiment": "neutral",
#                         "text": "變左瘦蚊😂",
#                         "timestamp": 1753872072
#                     },
#                     {
#                         "likes_count": 16,
#                         "owner_username": "1s2w1s8",
#                         "sentiment": "negative",
#                         "text": "原來都有幾多人？好似我咁唔明喎😅",
#                         "timestamp": 1753878002
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "hang_on_a_minute_aa",
#                         "sentiment": "negative",
#                         "text": "0分",
#                         "timestamp": 1753971180
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "kui_law",
#                         "sentiment": "negative",
#                         "text": "好難笑得出",
#                         "timestamp": 1754016787
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "pure_econ",
#                         "sentiment": "negative",
#                         "text": "完全唔get",
#                         "timestamp": 1753881832
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "jvardyhong",
#                         "sentiment": "neutral",
#                         "text": "知唔知長頸鹿最怕咩病？  答案係。。。喉嚨痛",
#                         "timestamp": 1754214745
#                     },
#                     {
#                         "likes_count": 22,
#                         "owner_username": "hotairballoon_96",
#                         "sentiment": "neutral",
#                         "text": "\"自從我有記憶嗰日開始\"",
#                         "timestamp": 1753871085
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "kcwmak",
#                         "sentiment": "negative",
#                         "text": "聽完，非洲都變冷凍。。。。。",
#                         "timestamp": 1753962831
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "yogaholi_ca",
#                         "sentiment": "negative",
#                         "text": "唔明",
#                         "timestamp": 1753879804
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "jonywong",
#                         "sentiment": "neutral",
#                         "text": "笑點係... 小明媽媽隔左好耐先帶小明去睇醫生？",
#                         "timestamp": 1753967626
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "alan_twy_",
#                         "sentiment": "negative",
#                         "text": "聽完覺得0明，唔係小明",
#                         "timestamp": 1754192553
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "ee_paulee",
#                         "sentiment": "negative",
#                         "text": "好冷",
#                         "timestamp": 1754005712
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "benjamin.s.chan",
#                         "sentiment": "negative",
#                         "text": "0",
#                         "timestamp": 1754000810
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "newpunkpower",
#                         "sentiment": "negative",
#                         "text": "睇兩次先覺得冇咁尷尬",
#                         "timestamp": 1753954361
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "carltonlau2007",
#                         "sentiment": "negative",
#                         "text": "我係5係要笑？...",
#                         "timestamp": 1753944025
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "mo_lai",
#                         "sentiment": "positive",
#                         "text": "肥蚊瘦左好多😮",
#                         "timestamp": 1753931676
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "iamdobe33",
#                         "sentiment": "neutral",
#                         "text": "肥蚊係咪瘦左😮",
#                         "timestamp": 1753922194
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "5i0l3t",
#                         "sentiment": "neutral",
#                         "text": "",
#                         "timestamp": 1753898239
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "himokeven2025",
#                         "sentiment": "positive",
#                         "text": "以為解扯旗",
#                         "timestamp": 1753895444
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "neutral",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1753894283
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "pakki_qqtoffee",
#                         "sentiment": "neutral",
#                         "text": "我都想見衛詩雅",
#                         "timestamp": 1753891926
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "chelseaghost111",
#                         "sentiment": "neutral",
#                         "text": "肥蚊瘦左咁多？\n\n定係我太耐無睇小薯茄？",
#                         "timestamp": 1753879620
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "sunrain_99",
#                         "sentiment": "negative",
#                         "text": "從細變大",
#                         "timestamp": 1753878531
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "alexander_chan1613",
#                         "sentiment": "negative",
#                         "text": "只有一分😂sorry🤣",
#                         "timestamp": 1753877909
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "_willchoi_",
#                         "sentiment": "negative",
#                         "text": "💙🧟‍♂️🤦🏿‍♂️",
#                         "timestamp": 1753877740
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "lokchunyip",
#                         "sentiment": "positive",
#                         "text": "唔明",
#                         "timestamp": 1753874274
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "edmundlo",
#                         "sentiment": "neutral",
#                         "text": "阿蚊好fit!",
#                         "timestamp": 1753873551
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "wmy0068",
#                         "sentiment": "negative",
#                         "text": "以為醫生會問長頸鹿點叫",
#                         "timestamp": 1753872872
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "wanderundwandern",
#                         "sentiment": "negative",
#                         "text": "1/5 一分係畀勇氣分",
#                         "timestamp": 1753872257
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "wckong627",
#                         "sentiment": "neutral",
#                         "text": "爛",
#                         "timestamp": 1753871879
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "ss_hker",
#                         "sentiment": "neutral",
#                         "text": "高Ling擺明係偏心啦！",
#                         "timestamp": 1753871651
#                     },
#                     {
#                         "likes_count": 5,
#                         "owner_username": "ack0110",
#                         "sentiment": "negative",
#                         "text": "又好似好有道理🦒會唔會係本身佢係長頸鹿",
#                         "timestamp": 1753870553
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "cc_chloesi",
#                         "sentiment": "positive",
#                         "text": "唔明",
#                         "timestamp": 1753870501
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "peterchanyt",
#                         "sentiment": "positive",
#                         "text": "肥蚊真係好努力，瘦左勁多",
#                         "timestamp": 1753870408
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "bujaii3o6",
#                         "sentiment": "neutral",
#                         "text": "😂😂🦒",
#                         "timestamp": 1753870280
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "negative",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1753870015
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "fungisaac622",
#                         "sentiment": "negative",
#                         "text": "唔明",
#                         "timestamp": 1753869993
#                     },
#                     {
#                         "likes_count": 17,
#                         "owner_username": "chloekomuro",
#                         "sentiment": "positive",
#                         "text": "睇唔明，即係嗰隻真係長頸鹿黎？",
#                         "timestamp": 1753869833
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "",
#                         "sentiment": "neutral",
#                         "text": "童童💚",
#                         "timestamp": 1753869698
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 85781
#             },
#             {
#                 "caption": "薯茄mini game #23  對望挑戰！👀\n含住啖水忍住唔好亂咁噴！\n想睇我哋玩咩小遊戲就留言同我哋講啦！\n@tungtungdess @laiyingdesu \n#minigame #對望挑戰 #挑戰 #challenge #小遊戲 #小薯茄 #pomato #薯茄minigame",
#                 "comments_count": 22,
#                 "hashtags": [
#                     "23",
#                     "minigame",
#                     "對望挑戰",
#                     "挑戰",
#                     "challenge",
#                     "小遊戲",
#                     "小薯茄",
#                     "pomato",
#                     "薯茄minigame"
#                 ],
#                 "likes_count": 8181,
#                 "mentions": [
#                     "tungtungdess",
#                     "laiyingdesu"
#                 ],
#                 "post_id": "3687324096592898812",
#                 "post_url": "https://www.instagram.com/p/DMsAbrFKGr8/",
#                 "timestamp": 1753783334,
#                 "top_comments": [
#                     {
#                         "likes_count": 0,
#                         "owner_username": "winson_hui",
#                         "sentiment": "positive",
#                         "text": "😍😍😍😍😍",
#                         "timestamp": 1753888305
#                     },
#                     {
#                         "likes_count": 34,
#                         "owner_username": "ytc_1006",
#                         "sentiment": "positive",
#                         "text": "點解可以咁得意!!!!!😍🥰",
#                         "timestamp": 1753785469
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "loreen1204",
#                         "sentiment": "positive",
#                         "text": "😂😂😂",
#                         "timestamp": 1753859398
#                     },
#                     {
#                         "likes_count": 9,
#                         "owner_username": "lokie_k_",
#                         "sentiment": "positive",
#                         "text": "麗英史上最大隻眼嘅一集😂",
#                         "timestamp": 1753797318
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "dennisyau507",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1753786545
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "aucwvrg2vae4hudhzckf",
#                         "sentiment": "positive",
#                         "text": "😍😍😍",
#                         "timestamp": 1753849090
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "rcbananahk",
#                         "sentiment": "positive",
#                         "text": "❤️❤️",
#                         "timestamp": 1753846311
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "tamafaidesu",
#                         "sentiment": "positive",
#                         "text": "Cute Cute",
#                         "timestamp": 1753796057
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "artlane24.potterystudio",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1753827260
#                     },
#                     {
#                         "likes_count": 92,
#                         "owner_username": "laiying.fan",
#                         "sentiment": "positive",
#                         "text": "勁cute！",
#                         "timestamp": 1753783697
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "nicky_tungdess",
#                         "sentiment": "neutral",
#                         "text": "人馬座女孩の遊戲",
#                         "timestamp": 1754155605
#                     },
#                     {
#                         "likes_count": 13,
#                         "owner_username": "siu.mor",
#                         "sentiment": "positive",
#                         "text": "第一次見咁得意既金魚🥰",
#                         "timestamp": 1753785585
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "henrychiu2024",
#                         "sentiment": "positive",
#                         "text": "好 cute 😂",
#                         "timestamp": 1753806944
#                     },
#                     {
#                         "likes_count": 10,
#                         "owner_username": "yychoi0503",
#                         "sentiment": "positive",
#                         "text": "童童好cute cute呀😍😍",
#                         "timestamp": 1753784667
#                     },
#                     {
#                         "likes_count": 20,
#                         "owner_username": "pomato.fanspage",
#                         "sentiment": "positive",
#                         "text": "史上最安靜嘅一集😂",
#                         "timestamp": 1753786604
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1753813067
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "tung.village",
#                         "sentiment": "positive",
#                         "text": "好cute 啊！🤤🤤",
#                         "timestamp": 1753788449
#                     },
#                     {
#                         "likes_count": 3,
#                         "owner_username": "ole_freddy167",
#                         "sentiment": "positive",
#                         "text": "童童成隻金魚blue blue blue咁😂",
#                         "timestamp": 1753784977
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "ry8502_6688",
#                         "sentiment": "positive",
#                         "text": "童童😍😍😍😍😍😍😍😍",
#                         "timestamp": 1753784344
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "lookingfor_gio",
#                         "sentiment": "neutral",
#                         "text": "Rummbikcu",
#                         "timestamp": 1753784279
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "brian.nz.418",
#                         "sentiment": "positive",
#                         "text": "童童💚💚💚",
#                         "timestamp": 1753783720
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "horoscope_for_your_life",
#                         "sentiment": "neutral",
#                         "text": "想知道每日星座運勢嗎？\n請follow及留意我的ig🙈\n每日更新👍🏻",
#                         "timestamp": 1753783520
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 67982
#             },
#             {
#                 "caption": "【小辯論 #16 揀位哲學】揀啱位=識做人？揀位の處世之道｜Pomato 小薯茄\n\n我哋每一日都面臨大大小小唔同嘅選擇！今次揀位小辯論就設定咗5個極端情況，身處其中嘅你又會點揀呢？\n歡迎大家喺留言展開激烈 （但禮貌）嘅討論！\n\n#小薯茄 #小辯論 #揀位 #處世之道 #識做人",
#                 "comments_count": 22,
#                 "hashtags": [
#                     "16",
#                     "小薯茄",
#                     "小辯論",
#                     "揀位",
#                     "處世之道",
#                     "識做人"
#                 ],
#                 "likes_count": 4822,
#                 "mentions": [],
#                 "post_id": "3686674308605705384",
#                 "post_url": "https://www.instagram.com/p/DMpssA3AHyo/",
#                 "timestamp": 1753705873,
#                 "top_comments": [
#                     {
#                         "likes_count": 59,
#                         "owner_username": "150.is.mine_",
#                         "sentiment": "positive",
#                         "text": "B😂😂😂我會望住咬然後咬到ABC三個點變返做一條直線😂😂😂",
#                         "timestamp": 1753718987
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "dennisyau507",
#                         "sentiment": "positive",
#                         "text": "❤️",
#                         "timestamp": 1753719092
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "benson.wong.106",
#                         "sentiment": "positive",
#                         "text": "我選擇A😂😆",
#                         "timestamp": 1753708817
#                     },
#                     {
#                         "likes_count": 10,
#                         "owner_username": "chung_alvin",
#                         "sentiment": "positive",
#                         "text": "童童點夠朱英嚟😂",
#                         "timestamp": 1753711453
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "yau_uu_",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️🔥🔥🔥🔥🔥",
#                         "timestamp": 1753705952
#                     },
#                     {
#                         "likes_count": 64,
#                         "owner_username": "winnieee_.13",
#                         "sentiment": "positive",
#                         "text": "朱英好有默契🔥🔥🔥",
#                         "timestamp": 1753706278
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "domlcw0725",
#                         "sentiment": "positive",
#                         "text": "D 一啖食晒",
#                         "timestamp": 1753708885
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "118hei",
#                         "sentiment": "positive",
#                         "text": "包邊食半飽，餡既美味會減半，所以趁熱辣辣就要享受先",
#                         "timestamp": 1754132008
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "da.phne0702",
#                         "sentiment": "positive",
#                         "text": "obviously B❤️",
#                         "timestamp": 1753821523
#                     },
#                     {
#                         "likes_count": 15,
#                         "owner_username": "moon.cytt",
#                         "sentiment": "positive",
#                         "text": "一定係直接抌咗前後兩塊包，淨係食個餡",
#                         "timestamp": 1753710714
#                     },
#                     {
#                         "likes_count": 6,
#                         "owner_username": "rachelspocket",
#                         "sentiment": "positive",
#                         "text": "第一題，我同童童一樣呀！😂😂",
#                         "timestamp": 1753706755
#                     },
#                     {
#                         "likes_count": 1,
#                         "owner_username": "brian.nz.418",
#                         "sentiment": "positive",
#                         "text": "童童💚💚💚",
#                         "timestamp": 1753705910
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "xmy2ctmh",
#                         "sentiment": "positive",
#                         "text": "❤️❤️❤️❤️❤️",
#                         "timestamp": 1753728027
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "gwaihak",
#                         "sentiment": "positive",
#                         "text": "B!!!!!!!",
#                         "timestamp": 1753766922
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "_.slxys._",
#                         "sentiment": "positive",
#                         "text": "🫶🏻✨️",
#                         "timestamp": 1753707700
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "samuelsha666",
#                         "sentiment": "positive",
#                         "text": "A",
#                         "timestamp": 1754567512
#                     },
#                     {
#                         "likes_count": 15,
#                         "owner_username": "chingyanfu",
#                         "sentiment": "positive",
#                         "text": "B for sure",
#                         "timestamp": 1753723416
#                     },
#                     {
#                         "likes_count": 17,
#                         "owner_username": "jefferykwan",
#                         "sentiment": "positive",
#                         "text": "B!!!",
#                         "timestamp": 1753713391
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "leung_polin",
#                         "sentiment": "positive",
#                         "text": "B",
#                         "timestamp": 1753708125
#                     },
#                     {
#                         "likes_count": 0,
#                         "owner_username": "rosaa0326",
#                         "sentiment": "positive",
#                         "text": "B😂",
#                         "timestamp": 1753707527
#                     },
#                     {
#                         "likes_count": 2,
#                         "owner_username": "fungisaac622",
#                         "sentiment": "positive",
#                         "text": "B",
#                         "timestamp": 1753706842
#                     },
#                     {
#                         "likes_count": 81,
#                         "owner_username": "hailey1.21",
#                         "sentiment": "positive",
#                         "text": "朱英！！！",
#                         "timestamp": 1753705985
#                     }
#                 ],
#                 "type": "Video",
#                 "video_view_count": 50508
#             }
#         ],
#         "username": "pomatohk"
#     },
#     "task_type": "profile_tracking",
#     "user_id": "c6a2af04-98e8-4fb6-a38b-b3e275851a76"
# }

# %% [markdown]
# ## Sentiment Analysis Summary
#
# Get a comprehensive sentiment analysis summary for your tracked profiles.

# %%
# Get sentiment summary - Select task from server immediately
print("🎯 Select a task for sentiment analysis:")
selected_task_id = smart_task_selector(auto_select_first=True)

if selected_task_id:
    print(f"\n📊 Analyzing sentiment for task: {selected_task_id}")
    sentiment_summary = get_sentiment_summary(selected_task_id)
    
    if sentiment_summary:
        print(f"📊 Sentiment Analysis Summary")
        print(f"=" * 40)
        print(f"📈 Overall Sentiment: {sentiment_summary['overall_sentiment'].upper()}")
        print(f"💬 Total Comments Analyzed: {sentiment_summary['total_comments']}")
        
        if sentiment_summary['total_comments'] > 0:
            print(f"\n📋 Sentiment Distribution:")
            for sentiment, count in sentiment_summary['sentiment_distribution'].items():
                percentage = sentiment_summary['sentiment_percentages'][sentiment]
                emoji = {'positive': '😊', 'negative': '😞', 'neutral': '😐'}[sentiment]
                print(f"   {emoji} {sentiment.capitalize()}: {count} comments ({percentage:.1f}%)")
            
            # Create a simple visual representation
            print(f"\n📊 Visual Distribution:")
            max_width = 30
            for sentiment, percentage in sentiment_summary['sentiment_percentages'].items():
                bar_width = int((percentage / 100) * max_width)
                bar = "█" * bar_width + "░" * (max_width - bar_width)
                emoji = {'positive': '😊', 'negative': '😞', 'neutral': '😐'}[sentiment]
                print(f"   {emoji} {sentiment.capitalize():8} |{bar}| {percentage:.1f}%")
        else:
            print("\n❌ No comments found to analyze.")
    else:
        print("❌ No sentiment data available. Make sure the task has been scraped.")
else:
    print("❌ No task selected or no tasks available on server.")

# %% [markdown]
# ## Compare Multiple Profiles
#
# Compare sentiment analysis across multiple tracked profiles.

# %%
# Compare sentiment across all tracked profiles - Updated to fetch fresh data from server
tasks_from_server = get_tracking_tasks()
if tasks_from_server and len(tasks_from_server) > 0:
    print("📊 Sentiment Comparison Across All Profiles")
    print("=" * 50)
    
    comparison_data = []
    
    # Get fresh task data from server instead of using cached all_task_ids
    for task in tasks_from_server:
        task_id = task['_id']
        task_details = get_task_details(task_id)
        if task_details:
            sentiment_summary = get_sentiment_summary(task_id)
            
            if sentiment_summary and sentiment_summary['total_comments'] > 0:
                comparison_data.append({
                    'Profile': f"@{task_details['target_profile']}",
                    'Type': 'Competitor' if task_details['is_competitor'] else 'Own',
                    'Overall': sentiment_summary['overall_sentiment'].title(),
                    'Positive %': f"{sentiment_summary['sentiment_percentages']['positive']:.1f}%",
                    'Negative %': f"{sentiment_summary['sentiment_percentages']['negative']:.1f}%",
                    'Neutral %': f"{sentiment_summary['sentiment_percentages']['neutral']:.1f}%",
                    'Total Comments': sentiment_summary['total_comments']
                })
    
    if comparison_data:
        comparison_df = pd.DataFrame(comparison_data)
        display(comparison_df)
        
        # Find best and worst performing profiles
        print(f"\n🏆 Analysis Insights:")
        
        own_profiles = [row for row in comparison_data if row['Type'] == 'Own']
        competitor_profiles = [row for row in comparison_data if row['Type'] == 'Competitor']
        
        if own_profiles:
            best_own = max(own_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            print(f"   🥇 Best performing own profile: {best_own['Profile']} ({best_own['Positive %']} positive)")
        
        if competitor_profiles:
            best_competitor = max(competitor_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            worst_competitor = min(competitor_profiles, key=lambda x: float(x['Positive %'].replace('%', '')))
            print(f"   🎯 Best competitor: {best_competitor['Profile']} ({best_competitor['Positive %']} positive)")
            print(f"   📉 Worst competitor: {worst_competitor['Profile']} ({worst_competitor['Positive %']} positive)")
    else:
        print("❌ No sentiment data available for comparison. Make sure tasks have been scraped.")
else:
    print("❌ No tasks available for comparison. Create some tasks first using the cells above.")

# %% [markdown]
# ## 🗑️ Task Delete
#
# Let's add functionality to view and delete specific tracking tasks.

# %%
# View and Delete Specific Tasks
def view_and_delete_tasks():
    """Interactive function to view tasks and select one to delete"""
    print("📋 Your Instagram Tracking Tasks:")
    print("=" * 50)
    
    # Get all tasks
    tasks = get_tracking_tasks()
    
    if not tasks:
        print("❌ No tasks found.")
        return
    
    # Display tasks with numbers
    for i, task in enumerate(tasks, 1):
        status_emoji = "✅" if task.get("status") == "active" else "⏸️"
        competitor_text = "🏢 Competitor" if task.get("is_competitor") else "👤 Own Profile"
        
        print(f"{i}. {status_emoji} @{task['target_profile']} ({competitor_text})")
        print(f"   📅 Created: {task.get('created_at', 'Unknown')}")
        print(f"   🔄 Last Scraped: {task.get('last_scraped', 'Never')}")
        print(f"   🆔 Task ID: {task['_id']}")
        print()
    
    # Ask user to select a task to delete
    try:
        selection = input(f"Enter task number to DELETE (1-{len(tasks)}) or 'q' to quit: ").strip()
        
        if selection.lower() == 'q':
            print("👋 Operation cancelled.")
            return
        
        task_num = int(selection)
        if 1 <= task_num <= len(tasks):
            selected_task = tasks[task_num - 1]
            
            # Confirm deletion
            confirm = input(f"⚠️  Are you sure you want to DELETE @{selected_task['target_profile']}? (yes/no): ").strip().lower()
            
            if confirm in ['yes', 'y']:
                success = delete_tracking_task(selected_task['_id'])
                if success:
                    print(f"✅ Successfully deleted tracking task for @{selected_task['target_profile']}")
                else:
                    print(f"❌ Failed to delete task for @{selected_task['target_profile']}")
            else:
                print("👋 Deletion cancelled.")
        else:
            print("❌ Invalid selection. Please enter a valid task number.")
            
    except ValueError:
        print("❌ Invalid input. Please enter a number or 'q'.")
    except KeyboardInterrupt:
        print("\n👋 Operation cancelled.")

# Run the interactive task deletion
view_and_delete_tasks()
# Out:
# 📋 Your Instagram Tracking Tasks:
# ==================================================
# ✓ Found 0 tracking tasks
# ❌ No tasks found.

# %% [markdown]
# ## ⚠️ Account Deletion
#
# **WARNING**: This will permanently delete the demo account and ALL associated data, including Instagram tracking tasks!

# %%
# Delete Demo Account (USE WITH CAUTION!)
def delete_demo_account():
    """Delete the demo account and all associated data"""
    print("⚠️  ACCOUNT DELETION WARNING ⚠️")
    print("=" * 50)
    print("This action will PERMANENTLY DELETE:")
    print("• The demo user account")
    print("• ALL Instagram tracking tasks")
    print("• ALL associated data")
    print("• This action CANNOT be undone!")
    print("=" * 50)
    
    try:
        # First confirmation
        confirm1 = input("Type 'DELETE' to continue or anything else to cancel: ").strip()
        
        if confirm1 != 'DELETE':
            print("👋 Account deletion cancelled.")
            return
        
        # Second confirmation with email
        current_email = "ig_tracking_test@email.com"  # The demo account email
        confirm2 = input(f"Type the email '{current_email}' to confirm: ").strip()
        
        if confirm2 != current_email:
            print("❌ Email confirmation failed. Account deletion cancelled.")
            return
        
        # Proceed with deletion
        print("\n🗑️  Deleting account...")
        success = client.delete_account()
        
        if success:
            print("✅ Demo account successfully deleted!")
            print("📋 All Instagram tracking tasks have been removed.")
            print("🔒 Session token invalidated.")
            print("\n👋 Thank you for trying the Instagram Tracking Service!")
            
            # Clear the session token
            client.session_token = None
        else:
            print("❌ Failed to delete account. Please try again or contact support.")
            
    except KeyboardInterrupt:
        print("\n👋 Account deletion cancelled.")

delete_demo_account()
